# %%
import pandas as pd

# %%
url = "http://snap.stanford.edu/data/index.html"

# %%
tables = pd.concat([
    df
    for df in pd.read_html(url)
    if all(col in df.columns for col in ("Name", "Type", "Nodes", "Edges"))
])

# %%
tables
# Out:
#                    Name                          Type             Nodes  \
# 0          ego-Facebook                    Undirected              4039
# 1             ego-Gplus                      Directed            107614
# 2           ego-Twitter                      Directed             81306
# 3         soc-Epinions1                      Directed             75879
# 4      soc-LiveJournal1                      Directed           4847571
# ..                  ...                           ...               ...
# 0              twitter7                        Tweets  17,069,982 users
# 1          memetracker9                         Memes        96 million
# 2       ksc-time-series                   Time Series              2000
# 3         higgs-twitter                        Tweets            456631
# 0   comm-f2f-Resistance  Weighted, Directed, Temporal               451
#
#                  Edges                                        Description  \
# ...
