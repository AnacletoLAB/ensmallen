# %%
import re
import glob
import json

# %%
path = "../../graph/src/*.rs"

# %%
setup = """
use super::*;
use arbitrary::Arbitrary;

#[derive(Arbitrary, Debug, Clone)]
pub struct FromVecHarnessParams {
    pub directed: bool,
    pub directed_edge_list: bool,
    pub ignore_duplicated_nodes: bool,
    pub ignore_duplicated_edges: bool,
    pub verbose: bool,
    pub numeric_edge_types_ids: bool,
    pub numeric_node_ids: bool,
    pub numeric_edge_node_ids: bool,
    pub numeric_node_types_ids: bool,
    pub has_node_types: bool,
    pub has_edge_types: bool,
    pub has_weights: bool,
    pub name: String,
    pub edges: Vec<Result<StringQuadruple, String>>,
    pub nodes: Option<Vec<Result<(String, Option<Vec<String>>), String>>>,
}

"""

# %%
def read_file(path):
    with open(path, "r") as f:
        return f.read()
    
def read_files(path):
    return [
        read_file(file)
        for file in glob.glob(path)
    ]

# %%
files = read_files(path)

# %%
def remove_prefix(text, prefix):
    if text.startswith(prefix):
        return text[len(prefix):]
    return text  # or whatever

def parse_arguments(arguments):
    flat = [
        remove_prefix(x.strip(), "mut").strip()
        for comb in arguments.split(":")
        for x in comb.rsplit(",", 1)
    ]
    
    return [
            (arg_name, arg_type)
            for (arg_name, arg_type) in zip(flat[::2], flat[1::2])
    ]

# %%
#  r"pub\s+fn\s+([^\(\{]+?)\((self|&\s*self|&mut\s+self|&'.\s+self)?([^\)\{]+?)\)\s*(:?->\s*([^\{]+?))\{"

# %%
functions = [
    x
    for file in files
    for x in re.findall(
        r"fn\s+([^\{]+?)\{", 
        "\n".join(
            re.findall(
                "impl\s+Graph\s+\{.+\}", 
                file.replace("\n", "")
            )
        ) or "", 
        re.MULTILINE
    )
    if not any(
        e in x
        for e in [
            "impl", 
            "Fn", 
            "Iter", 
            "NodeFileReader", 
            "EdgeFileReader", 
            "Graph", 
            "Compute_hash_Params",
            "&str"
            "&String",
            "SingleWalkParameters",
            "WalksParameters",
            "&[u32]",
            "WalkWeights",
            "Self",
            "&"
        ]
    )
]
len(functions)
# Out:
# 2

# %%
functions
# Out:
# ['validate_weight(weight: WeightT) -> Result<WeightT, String> ',
#  'parse_weight(weight: String) -> Result<WeightT, String> ']

# %%
re.findall(r"\w+(<.+?>)\(\s*(self|&self|&\s*mut\s*self),\s+(.+)", functions[0])
# Out:
# []

# %%
functions_info = {
    function_name:{
        "arguments":parse_arguments(arguments),
        "return_type":return_type.strip(),
    }
    for function in functions
    fo
}
# Out:
#   File "<ipython-input-83-0998927f304a>", line 7
#     fo
#     ^
# SyntaxError: invalid syntax

# %%
print(json.dumps(functions_info, indent=4))
# Out:
# {
#     "random_spanning_arborescence_kruskal": {
#         "arguments": [
#             [
#                 "&self",
#                 "random_state"
#             ],
#             [
#                 "EdgeT",
#                 "unwanted_edge_types"
#             ],
#             [
#                 "&Option<HashSet<Option<EdgeTypeT>>>",
#                 "verbose"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "(HashSet<(NodeT, NodeT)>, Vec<NodeT>, NodeT, NodeT, NodeT)"
#     },
#     "spanning_arborescence_kruskal": {
#         "arguments": [
#             [
#                 "&self",
#                 "verbose"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "(HashSet<(NodeT, NodeT)>, Vec<NodeT>, NodeT, NodeT, NodeT)"
#     },
#     "spanning_arborescence": {
#         "arguments": [
#             [
#                 "&self",
#                 "verbose"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "Result<(usize, impl Iterator<Item = (NodeT, NodeT)> + '_), String>"
#     },
#     "connected_components": {
#         "arguments": [
#             [
#                 "&self",
#                 "verbose"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "Result<(Vec<NodeT>, NodeT, NodeT, NodeT), String>"
#     },
#     "new<S: Into<String>>": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ],
#             [
#                 "unique_self_loop_number",
#                 "NodeT"
#             ],
#             [
#                 "self_loop_number",
#                 "EdgeT"
#             ],
#             [
#                 "not_singleton_nodes_number",
#                 "NodeT"
#             ],
#             [
#                 "singleton_nodes_with_self_loops_number",
#                 "NodeT"
#             ],
#             [
#                 "unique_edges_number",
#                 "EdgeT"
#             ],
#             [
#                 "edges",
#                 "EliasFano"
#             ],
#             [
#                 "unique_sources",
#                 "EliasFano"
#             ],
#             [
#                 "nodes",
#                 "Vocabulary<NodeT>"
#             ],
#             [
#                 "node_bit_mask",
#                 "EdgeT"
#             ],
#             [
#                 "node_bits",
#                 "u8"
#             ],
#             [
#                 "edge_types",
#                 "Option<EdgeTypeVocabulary>"
#             ],
#             [
#                 "name",
#                 "S"
#             ],
#             [
#                 "weights",
#                 "Option<Vec<WeightT>>"
#             ],
#             [
#                 "node_types",
#                 "Option<NodeTypeVocabulary>"
#             ]
#         ],
#         "return_type": "Graph"
#     },
#     "overlaps": {
#         "arguments": [
#             [
#                 "",
#                 "other"
#             ]
#         ],
#         "return_type": "Result<bool, String>"
#     },
#     "contains": {
#         "arguments": [
#             [
#                 "",
#                 "other"
#             ]
#         ],
#         "return_type": "Result<bool, String>"
#     },
#     "node2vec<'a>": {
#         "arguments": [
#             [
#                 "&'a self",
#                 "walk_parameters"
#             ],
#             [
#                 "&'a WalksParameters",
#                 "quantity"
#             ],
#             [
#                 "NodeT",
#                 "window_size"
#             ],
#             [
#                 "usize",
#                 ""
#             ]
#         ],
#         "return_type": "Result<impl ParallelIterator<Item = (Vec<NodeT>, NodeT)> + 'a, String>"
#     },
#     "cooccurence_matrix": {
#         "arguments": [
#             [
#                 "&self",
#                 "walks_parameters"
#             ],
#             [
#                 "&WalksParameters",
#                 "window_size"
#             ],
#             [
#                 "usize",
#                 "verbose"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "Result<(Words, Words, Frequencies), String>"
#     },
#     "link_prediction_degrees<'a>": {
#         "arguments": [
#             [
#                 "&'a self",
#                 "idx"
#             ],
#             [
#                 "u64",
#                 "batch_size"
#             ],
#             [
#                 "usize",
#                 "normalize"
#             ],
#             [
#                 "bool",
#                 "negative_samples"
#             ],
#             [
#                 "f64",
#                 "avoid_false_negatives"
#             ],
#             [
#                 "bool",
#                 "maximal_sampling_attempts"
#             ],
#             [
#                 "usize",
#                 "graph_to_avoid"
#             ],
#             [
#                 "&'a Option<&Graph>",
#                 ""
#             ]
#         ],
#         "return_type": "Result<impl ParallelIterator<Item = (usize, f64, f64, bool)> + 'a, String>"
#     },
#     "link_prediction_ids<'a>": {
#         "arguments": [
#             [
#                 "&'a self",
#                 "idx"
#             ],
#             [
#                 "u64",
#                 "batch_size"
#             ],
#             [
#                 "usize",
#                 "negative_samples"
#             ],
#             [
#                 "f64",
#                 "avoid_false_negatives"
#             ],
#             [
#                 "bool",
#                 "maximal_sampling_attempts"
#             ],
#             [
#                 "usize",
#                 "graph_to_avoid"
#             ],
#             [
#                 "&'a Option<&Graph>",
#                 ""
#             ]
#         ],
#         "return_type": "Result<impl ParallelIterator<Item = (usize, NodeT, NodeT, bool)> + 'a, String>"
#     },
#     "validate_weight": {
#         "arguments": [
#             [
#                 "weight",
#                 "WeightT"
#             ]
#         ],
#         "return_type": "Result<WeightT, String>"
#     },
#     "parse_weight": {
#         "arguments": [
#             [
#                 "weight",
#                 "String"
#             ]
#         ],
#         "return_type": "Result<WeightT, String>"
#     },
#     "are_nodes_remappable": {
#         "arguments": [
#             [
#                 "",
#                 "other"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "remap": {
#         "arguments": [
#             [
#                 "",
#                 "other"
#             ],
#             [
#                 "&Graph",
#                 "verbose"
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "set_all_edge_types<S: Into<String>>": {
#         "arguments": [
#             [
#                 "self",
#                 "edge_type"
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "set_all_node_types<S: Into<String>>": {
#         "arguments": [
#             [
#                 "self",
#                 "node_type"
#             ]
#         ],
#         "return_type": "Graph"
#     },
#     "enable": {
#         "arguments": [
#             [
#                 "&mut self",
#                 "vector_sources"
#             ],
#             [
#                 "bool",
#                 "vector_destinations"
#             ],
#             [
#                 "bool",
#                 "vector_outbounds"
#             ],
#             [
#                 "bool",
#                 "cache_size"
#             ],
#             [
#                 "Option<f64>",
#                 ""
#             ]
#         ],
#         "return_type": "Result<(), String>"
#     },
#     "strongly_connected_components": {
#         "arguments": [],
#         "return_type": "Vec<HashSet<NodeT>>"
#     },
#     "filter": {
#         "arguments": [
#             [
#                 "&self",
#                 "node_names"
#             ],
#             [
#                 "Option<Vec<String>>",
#                 "node_types"
#             ],
#             [
#                 "Option<Vec<Option<String>>>",
#                 "edge_types"
#             ],
#             [
#                 "Option<Vec<Option<String>>>",
#                 "min_weight"
#             ],
#             [
#                 "Option<WeightT>",
#                 "max_weight"
#             ],
#             [
#                 "Option<WeightT>",
#                 "verbose"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "get_filtered_neighbours_range": {
#         "arguments": [
#             [
#                 "&self",
#                 "src"
#             ],
#             [
#                 "NodeT",
#                 "node_names"
#             ],
#             [
#                 "Option<Vec<String>>",
#                 "node_types"
#             ],
#             [
#                 "Option<Vec<Option<String>>>",
#                 "edge_types"
#             ],
#             [
#                 "Option<Vec<Option<String>>>",
#                 "min_weight"
#             ],
#             [
#                 "Option<WeightT>",
#                 "max_weight"
#             ],
#             [
#                 "Option<WeightT>",
#                 ""
#             ]
#         ],
#         "return_type": "Result<impl Iterator<Item = NodeT> + '_, String>"
#     },
#     "degrees_product": {
#         "arguments": [
#             [
#                 "",
#                 "one"
#             ],
#             [
#                 "NodeT",
#                 "two"
#             ]
#         ],
#         "return_type": "Result<usize, String>"
#     },
#     "jaccard_index": {
#         "arguments": [
#             [
#                 "",
#                 "one"
#             ],
#             [
#                 "NodeT",
#                 "two"
#             ]
#         ],
#         "return_type": "Result<f64, String>"
#     },
#     "adamic_adar_index": {
#         "arguments": [
#             [
#                 "",
#                 "one"
#             ],
#             [
#                 "NodeT",
#                 "two"
#             ]
#         ],
#         "return_type": "Result<f64, String>"
#     },
#     "resource_allocation_index": {
#         "arguments": [
#             [
#                 "",
#                 "one"
#             ],
#             [
#                 "NodeT",
#                 "two"
#             ]
#         ],
#         "return_type": "Result<f64, String>"
#     },
#     "traps_rate": {
#         "arguments": [],
#         "return_type": "f64"
#     },
#     "degrees_mean": {
#         "arguments": [],
#         "return_type": "f64"
#     },
#     "get_undirected_edges_number": {
#         "arguments": [],
#         "return_type": "EdgeT"
#     },
#     "get_edges_number": {
#         "arguments": [],
#         "return_type": "EdgeT"
#     },
#     "degrees_median": {
#         "arguments": [],
#         "return_type": "NodeT"
#     },
#     "max_degree": {
#         "arguments": [],
#         "return_type": "NodeT"
#     },
#     "min_degree": {
#         "arguments": [],
#         "return_type": "NodeT"
#     },
#     "degrees_mode": {
#         "arguments": [],
#         "return_type": "NodeT"
#     },
#     "get_self_loop_number": {
#         "arguments": [],
#         "return_type": "EdgeT"
#     },
#     "get_unique_self_loop_number": {
#         "arguments": [],
#         "return_type": "NodeT"
#     },
#     "get_self_loop_rate": {
#         "arguments": [],
#         "return_type": "f64"
#     },
#     "connected_components_number": {
#         "arguments": [
#             [
#                 "",
#                 "verbose"
#             ]
#         ],
#         "return_type": "(NodeT, NodeT, NodeT)"
#     },
#     "get_singleton_nodes_number": {
#         "arguments": [],
#         "return_type": "NodeT"
#     },
#     "get_singleton_nodes_with_self_loops_number": {
#         "arguments": [],
#         "return_type": "NodeT"
#     },
#     "get_not_singleton_nodes_number": {
#         "arguments": [],
#         "return_type": "NodeT"
#     },
#     "density": {
#         "arguments": [],
#         "return_type": "f64"
#     },
#     "report": {
#         "arguments": [],
#         "return_type": "DefaultHashMap<&str, String>"
#     },
#     "overlap_textual_report": {
#         "arguments": [
#             [
#                 "",
#                 "other"
#             ],
#             [
#                 "&Graph",
#                 "verbose"
#             ]
#         ],
#         "return_type": "Result<String, String>"
#     },
#     "textual_report": {
#         "arguments": [
#             [
#                 "",
#                 "verbose"
#             ]
#         ],
#         "return_type": "Result<String, String>"
#     },
#     "remove": {
#         "arguments": [
#             [
#                 "&self",
#                 "allow_nodes_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "deny_nodes_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "allow_node_types_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "deny_node_types_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "allow_edge_set"
#             ],
#             [
#                 "Option<HashSet<EdgeT>>",
#                 "deny_edge_set"
#             ],
#             [
#                 "Option<HashSet<EdgeT>>",
#                 "allow_edge_types_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "deny_edge_types_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "weights"
#             ],
#             [
#                 "bool",
#                 "node_types"
#             ],
#             [
#                 "bool",
#                 "edge_types"
#             ],
#             [
#                 "bool",
#                 "singletons"
#             ],
#             [
#                 "bool",
#                 "selfloops"
#             ],
#             [
#                 "bool",
#                 "verbose"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "remove_components": {
#         "arguments": [
#             [
#                 "&self",
#                 "node_names"
#             ],
#             [
#                 "Option<Vec<String>>",
#                 "node_types"
#             ],
#             [
#                 "Option<Vec<Option<String>>>",
#                 "edge_types"
#             ],
#             [
#                 "Option<Vec<Option<String>>>",
#                 "minimum_component_size"
#             ],
#             [
#                 "Option<NodeT>",
#                 "top_k_components"
#             ],
#             [
#                 "Option<NodeT>",
#                 "verbose"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "extract_uniform_node": {
#         "arguments": [
#             [
#                 "",
#                 "node"
#             ],
#             [
#                 "NodeT",
#                 "random_state"
#             ]
#         ],
#         "return_type": "NodeT"
#     },
#     "extract_node": {
#         "arguments": [
#             [
#                 "&self",
#                 "node"
#             ],
#             [
#                 "NodeT",
#                 "random_state"
#             ],
#             [
#                 "NodeT",
#                 "walk_weights"
#             ],
#             [
#                 "&WalkWeights",
#                 "min_edge_id"
#             ],
#             [
#                 "EdgeT",
#                 "max_edge_id"
#             ],
#             [
#                 "EdgeT",
#                 "destinations"
#             ],
#             [
#                 "&[NodeT]",
#                 "probabilistic_indices"
#             ],
#             [
#                 "&Option<Vec<u64>>",
#                 ""
#             ]
#         ],
#         "return_type": "(NodeT, EdgeT)"
#     },
#     "extract_edge": {
#         "arguments": [
#             [
#                 "&self",
#                 "src"
#             ],
#             [
#                 "NodeT",
#                 "dst"
#             ],
#             [
#                 "NodeT",
#                 "edge"
#             ],
#             [
#                 "EdgeT",
#                 "random_state"
#             ],
#             [
#                 "NodeT",
#                 "walk_weights"
#             ],
#             [
#                 "&WalkWeights",
#                 "min_edge_id"
#             ],
#             [
#                 "EdgeT",
#                 "max_edge_id"
#             ],
#             [
#                 "EdgeT",
#                 "destinations"
#             ],
#             [
#                 "&[NodeT]",
#                 "previous_destinations"
#             ],
#             [
#                 "&[NodeT]",
#                 "probabilistic_indices"
#             ],
#             [
#                 "&Option<Vec<u64>>",
#                 ""
#             ]
#         ],
#         "return_type": "(NodeT, EdgeT)"
#     },
#     "random_walks_iter<'a>": {
#         "arguments": [
#             [
#                 "&'a self",
#                 "quantity"
#             ],
#             [
#                 "NodeT",
#                 "parameters"
#             ],
#             [
#                 "&'a WalksParameters",
#                 ""
#             ]
#         ],
#         "return_type": "Result<impl IndexedParallelIterator<Item = Vec<NodeT>> + 'a, String>"
#     },
#     "complete_walks_iter<'a>": {
#         "arguments": [
#             [
#                 "&'a self",
#                 "parameters"
#             ],
#             [
#                 "&'a WalksParameters",
#                 ""
#             ]
#         ],
#         "return_type": "Result<impl IndexedParallelIterator<Item = Vec<NodeT>> + 'a, String>"
#     },
#     "walk_iter<'a>": {
#         "arguments": [
#             [
#                 "&'a self",
#                 "quantity"
#             ],
#             [
#                 "NodeT",
#                 "to_node"
#             ]
#         ],
#         "return_type": "(NodeT, NodeT) + Sync + Send + 'a,        parameters: &'a WalksParameters,    ) -> Result<impl IndexedParallelIterator<Item = Vec<NodeT>> + 'a, String>"
#     },
#     "single_walk": {
#         "arguments": [
#             [
#                 "&self",
#                 "node"
#             ],
#             [
#                 "NodeT",
#                 "random_state"
#             ],
#             [
#                 "NodeT",
#                 "parameters"
#             ],
#             [
#                 "&SingleWalkParameters",
#                 ""
#             ]
#         ],
#         "return_type": "Vec<NodeT>"
#     },
#     "get_bipartite_edges": {
#         "arguments": [
#             [
#                 "&self",
#                 "removed_existing_edges"
#             ],
#             [
#                 "Option<bool>",
#                 "first_nodes_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "second_nodes_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "first_node_types_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "second_node_types_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 ""
#             ]
#         ],
#         "return_type": "Result<Vec<Vec<NodeT>>, String>"
#     },
#     "get_bipartite_edge_names": {
#         "arguments": [
#             [
#                 "&self",
#                 "removed_existing_edges"
#             ],
#             [
#                 "Option<bool>",
#                 "first_nodes_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "second_nodes_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "first_node_types_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "second_node_types_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 ""
#             ]
#         ],
#         "return_type": "Result<Vec<Vec<String>>, String>"
#     },
#     "get_star_edges": {
#         "arguments": [
#             [
#                 "&self",
#                 "central_node"
#             ],
#             [
#                 "String",
#                 "removed_existing_edges"
#             ],
#             [
#                 "Option<bool>",
#                 "star_points_nodes_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "star_points_node_types_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 ""
#             ]
#         ],
#         "return_type": "Result<Vec<Vec<NodeT>>, String>"
#     },
#     "get_star_edge_names": {
#         "arguments": [
#             [
#                 "&self",
#                 "central_node"
#             ],
#             [
#                 "String",
#                 "removed_existing_edges"
#             ],
#             [
#                 "Option<bool>",
#                 "star_points_nodes_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "star_points_node_types_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 ""
#             ]
#         ],
#         "return_type": "Result<Vec<Vec<String>>, String>"
#     },
#     "get_clique_edges": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "Option<bool>",
#                 "allow_self_loops"
#             ],
#             [
#                 "Option<bool>",
#                 "removed_existing_edges"
#             ],
#             [
#                 "Option<bool>",
#                 "allow_node_type_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "allow_node_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 ""
#             ]
#         ],
#         "return_type": "Vec<Vec<NodeT>>"
#     },
#     "get_clique_edge_names": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "Option<bool>",
#                 "allow_self_loops"
#             ],
#             [
#                 "Option<bool>",
#                 "removed_existing_edges"
#             ],
#             [
#                 "Option<bool>",
#                 "allow_node_type_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 "allow_node_set"
#             ],
#             [
#                 "Option<HashSet<String>>",
#                 ""
#             ]
#         ],
#         "return_type": "Vec<Vec<String>>"
#     },
#     "get_name": {
#         "arguments": [],
#         "return_type": "String"
#     },
#     "get_traps_number": {
#         "arguments": [],
#         "return_type": "EdgeT"
#     },
#     "has_traps": {
#         "arguments": [],
#         "return_type": "bool"
#     },
#     "is_directed": {
#         "arguments": [],
#         "return_type": "bool"
#     },
#     "has_weights": {
#         "arguments": [],
#         "return_type": "bool"
#     },
#     "has_edge_types": {
#         "arguments": [],
#         "return_type": "bool"
#     },
#     "has_selfloops": {
#         "arguments": [],
#         "return_type": "bool"
#     },
#     "is_singleton": {
#         "arguments": [
#             [
#                 "",
#                 "node_id"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "is_singleton_with_self_loops": {
#         "arguments": [
#             [
#                 "",
#                 "node_id"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "is_singleton_by_nide_name": {
#         "arguments": [
#             [
#                 "",
#                 "node_name"
#             ]
#         ],
#         "return_type": "Result<bool, String>"
#     },
#     "has_singletons": {
#         "arguments": [],
#         "return_type": "bool"
#     },
#     "has_singleton_nodes_with_self_loops_number": {
#         "arguments": [],
#         "return_type": "bool"
#     },
#     "get_sources": {
#         "arguments": [
#             [
#                 "",
#                 "directed"
#             ]
#         ],
#         "return_type": "Vec<NodeT>"
#     },
#     "get_source_names": {
#         "arguments": [
#             [
#                 "",
#                 "directed"
#             ]
#         ],
#         "return_type": "Vec<String>"
#     },
#     "get_destinations": {
#         "arguments": [
#             [
#                 "",
#                 "directed"
#             ]
#         ],
#         "return_type": "Vec<NodeT>"
#     },
#     "get_destination_names": {
#         "arguments": [
#             [
#                 "",
#                 "directed"
#             ]
#         ],
#         "return_type": "Vec<String>"
#     },
#     "get_node_names": {
#         "arguments": [],
#         "return_type": "Vec<String>"
#     },
#     "get_nodes": {
#         "arguments": [],
#         "return_type": "Vec<NodeT>"
#     },
#     "get_top_k_central_nodes": {
#         "arguments": [
#             [
#                 "",
#                 "k"
#             ]
#         ],
#         "return_type": "Vec<NodeT>"
#     },
#     "get_top_k_central_node_names": {
#         "arguments": [
#             [
#                 "",
#                 "k"
#             ]
#         ],
#         "return_type": "Vec<String>"
#     },
#     "get_edge_types": {
#         "arguments": [],
#         "return_type": "Option<Vec<Option<EdgeTypeT>>>"
#     },
#     "get_edge_type_name": {
#         "arguments": [
#             [
#                 "",
#                 "edge_type_id"
#             ]
#         ],
#         "return_type": "Option<String>"
#     },
#     "get_edge_type_names": {
#         "arguments": [],
#         "return_type": "Option<Vec<String>>"
#     },
#     "get_node_types": {
#         "arguments": [],
#         "return_type": "Option<Vec<Option<Vec<NodeTypeT>>>>"
#     },
#     "translate_node_type_id_vector": {
#         "arguments": [
#             [
#                 "&self",
#                 "node_type_id"
#             ],
#             [
#                 "Vec<NodeTypeT>",
#                 ""
#             ]
#         ],
#         "return_type": "Option<Vec<String>>"
#     },
#     "translate_node_type_id": {
#         "arguments": [
#             [
#                 "",
#                 "node_type_id"
#             ]
#         ],
#         "return_type": "Option<String>"
#     },
#     "get_weights": {
#         "arguments": [],
#         "return_type": "Option<Vec<WeightT>>"
#     },
#     "get_node_type_names": {
#         "arguments": [],
#         "return_type": "Option<Vec<String>>"
#     },
#     "get_unique_edges_number": {
#         "arguments": [],
#         "return_type": "EdgeT"
#     },
#     "get_max_encodable_edge_number": {
#         "arguments": [],
#         "return_type": "EdgeT"
#     },
#     "get_nodes_mapping": {
#         "arguments": [],
#         "return_type": "HashMap<String, NodeT>"
#     },
#     "get_edges": {
#         "arguments": [
#             [
#                 "",
#                 "directed"
#             ]
#         ],
#         "return_type": "Vec<Vec<NodeT>>"
#     },
#     "get_edge_names": {
#         "arguments": [
#             [
#                 "",
#                 "directed"
#             ]
#         ],
#         "return_type": "Vec<(String, String)>"
#     },
#     "get_unchecked_edge_type": {
#         "arguments": [
#             [
#                 "",
#                 "edge_id"
#             ]
#         ],
#         "return_type": "Option<EdgeTypeT>"
#     },
#     "get_unchecked_edge_weight": {
#         "arguments": [
#             [
#                 "",
#                 "edge_id"
#             ]
#         ],
#         "return_type": "Option<WeightT>"
#     },
#     "get_unchecked_node_type": {
#         "arguments": [
#             [
#                 "",
#                 "node_id"
#             ]
#         ],
#         "return_type": "Option<Vec<NodeTypeT>>"
#     },
#     "get_node_type_id_by_node_id": {
#         "arguments": [
#             [
#                 "",
#                 "node_id"
#             ]
#         ],
#         "return_type": "Result<Option<Vec<NodeTypeT>>, String>"
#     },
#     "get_edge_type": {
#         "arguments": [
#             [
#                 "",
#                 "edge_id"
#             ]
#         ],
#         "return_type": "Result<Option<EdgeTypeT>, String>"
#     },
#     "get_node_type_name": {
#         "arguments": [
#             [
#                 "",
#                 "node_id"
#             ]
#         ],
#         "return_type": "Option<Vec<String>>"
#     },
#     "get_edge_type_name_by_edge_id": {
#         "arguments": [
#             [
#                 "",
#                 "edge_id"
#             ]
#         ],
#         "return_type": "Option<String>"
#     },
#     "get_node_name": {
#         "arguments": [
#             [
#                 "",
#                 "node_id"
#             ]
#         ],
#         "return_type": "Result<String, String>"
#     },
#     "get_node_id": {
#         "arguments": [
#             [
#                 "",
#                 "node_name"
#             ]
#         ],
#         "return_type": "Result<NodeT, String>"
#     },
#     "get_node_type_id_by_node_name": {
#         "arguments": [
#             [
#                 "",
#                 "node_name"
#             ]
#         ],
#         "return_type": "Result<Option<Vec<NodeTypeT>>, String>"
#     },
#     "get_node_type_name_by_node_name": {
#         "arguments": [
#             [
#                 "",
#                 "node_name"
#             ]
#         ],
#         "return_type": "Result<Option<Vec<String>>, String>"
#     },
#     "has_node_by_name": {
#         "arguments": [
#             [
#                 "",
#                 "node_name"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "get_unchecked_node_id": {
#         "arguments": [
#             [
#                 "",
#                 "node_name"
#             ]
#         ],
#         "return_type": "NodeT"
#     },
#     "get_unchecked_edge_type_id": {
#         "arguments": [
#             [
#                 "",
#                 "edge_type"
#             ]
#         ],
#         "return_type": "Option<EdgeTypeT>"
#     },
#     "get_edge_weight": {
#         "arguments": [
#             [
#                 "",
#                 "edge_id"
#             ]
#         ],
#         "return_type": "Option<WeightT>"
#     },
#     "has_node_types": {
#         "arguments": [],
#         "return_type": "bool"
#     },
#     "has_multilabel_node_types": {
#         "arguments": [],
#         "return_type": "bool"
#     },
#     "get_unknown_node_types_number": {
#         "arguments": [],
#         "return_type": "NodeT"
#     },
#     "get_minimum_node_types_number": {
#         "arguments": [],
#         "return_type": "NodeT"
#     },
#     "has_unknown_node_types": {
#         "arguments": [],
#         "return_type": "bool"
#     },
#     "get_unknown_edge_types_number": {
#         "arguments": [],
#         "return_type": "EdgeT"
#     },
#     "get_minimum_edge_types_number": {
#         "arguments": [],
#         "return_type": "EdgeT"
#     },
#     "has_unknown_edge_types": {
#         "arguments": [],
#         "return_type": "bool"
#     },
#     "get_nodes_number": {
#         "arguments": [],
#         "return_type": "NodeT"
#     },
#     "get_node_components_vector": {
#         "arguments": [
#             [
#                 "",
#                 "verbose"
#             ]
#         ],
#         "return_type": "Vec<NodeT>"
#     },
#     "get_directed_edges_number": {
#         "arguments": [],
#         "return_type": "EdgeT"
#     },
#     "get_edge_types_number": {
#         "arguments": [],
#         "return_type": "EdgeTypeT"
#     },
#     "get_node_types_number": {
#         "arguments": [],
#         "return_type": "NodeTypeT"
#     },
#     "get_node_degrees": {
#         "arguments": [],
#         "return_type": "Vec<NodeT>"
#     },
#     "get_not_singletons": {
#         "arguments": [],
#         "return_type": "Vec<NodeT>"
#     },
#     "get_dense_node_mapping": {
#         "arguments": [],
#         "return_type": "HashMap<NodeT, NodeT>"
#     },
#     "get_unchecked_edge_count_by_edge_type": {
#         "arguments": [
#             [
#                 "",
#                 "edge_type"
#             ]
#         ],
#         "return_type": "EdgeT"
#     },
#     "get_edge_count_by_edge_type": {
#         "arguments": [
#             [
#                 "",
#                 "edge_type"
#             ]
#         ],
#         "return_type": "Result<EdgeT, String>"
#     },
#     "get_edge_type_id": {
#         "arguments": [
#             [
#                 "",
#                 "edge_type_name"
#             ]
#         ],
#         "return_type": "Result<Option<EdgeTypeT>, String>"
#     },
#     "get_edge_count_by_edge_type_name": {
#         "arguments": [
#             [
#                 "",
#                 "edge_type"
#             ]
#         ],
#         "return_type": "Result<EdgeT, String>"
#     },
#     "get_unchecked_node_count_by_node_type": {
#         "arguments": [
#             [
#                 "",
#                 "node_type"
#             ]
#         ],
#         "return_type": "NodeT"
#     },
#     "get_node_type_id": {
#         "arguments": [
#             [
#                 "",
#                 "node_type_name"
#             ]
#         ],
#         "return_type": "Result<NodeTypeT, String>"
#     },
#     "get_node_count_by_node_type": {
#         "arguments": [
#             [
#                 "",
#                 "node_type"
#             ]
#         ],
#         "return_type": "Result<NodeT, String>"
#     },
#     "get_node_count_by_node_type_name": {
#         "arguments": [
#             [
#                 "",
#                 "node_type"
#             ]
#         ],
#         "return_type": "Result<NodeT, String>"
#     },
#     "is_multigraph": {
#         "arguments": [],
#         "return_type": "bool"
#     },
#     "get_multigraph_edges_number": {
#         "arguments": [],
#         "return_type": "EdgeT"
#     },
#     "get_outbounds": {
#         "arguments": [],
#         "return_type": "Vec<EdgeT>"
#     },
#     "get_destination": {
#         "arguments": [
#             [
#                 "",
#                 "edge_id"
#             ]
#         ],
#         "return_type": "NodeT"
#     },
#     "get_destinations_range": {
#         "arguments": [
#             [
#                 "&self",
#                 "min_edge_id"
#             ],
#             [
#                 "EdgeT",
#                 "max_edge_id"
#             ],
#             [
#                 "EdgeT",
#                 ""
#             ]
#         ],
#         "return_type": "impl Iterator<Item = NodeT> + '_"
#     },
#     "get_neighbours_iter": {
#         "arguments": [
#             [
#                 "",
#                 "src"
#             ]
#         ],
#         "return_type": "impl Iterator<Item = NodeT> + '_"
#     },
#     "get_unique_sources_number": {
#         "arguments": [],
#         "return_type": "NodeT"
#     },
#     "get_source_nodes_number": {
#         "arguments": [],
#         "return_type": "NodeT"
#     },
#     "get_unchecked_edge_id": {
#         "arguments": [
#             [
#                 "&self",
#                 "src"
#             ],
#             [
#                 "NodeT",
#                 "dst"
#             ],
#             [
#                 "NodeT",
#                 "edge_type"
#             ],
#             [
#                 "Option<EdgeTypeT>",
#                 ""
#             ]
#         ],
#         "return_type": "EdgeT"
#     },
#     "get_edge_id": {
#         "arguments": [
#             [
#                 "&self",
#                 "src"
#             ],
#             [
#                 "NodeT",
#                 "dst"
#             ],
#             [
#                 "NodeT",
#                 "edge_type"
#             ],
#             [
#                 "Option<EdgeTypeT>",
#                 ""
#             ]
#         ],
#         "return_type": "Result<EdgeT, String>"
#     },
#     "has_edge": {
#         "arguments": [
#             [
#                 "",
#                 "src"
#             ],
#             [
#                 "NodeT",
#                 "dst"
#             ],
#             [
#                 "NodeT",
#                 "edge_type"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "get_edge_id_by_node_names": {
#         "arguments": [
#             [
#                 "&self",
#                 "src_name"
#             ],
#             [
#                 "&str",
#                 "dst_name"
#             ]
#         ],
#         "return_type": "Result<EdgeT, String>"
#     },
#     "has_edge_by_node_names": {
#         "arguments": [
#             [
#                 "&self",
#                 "src_name"
#             ],
#             [
#                 "&str",
#                 "dst_name"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "get_edge_id_with_type_by_node_names": {
#         "arguments": [
#             [
#                 "&self",
#                 "src_name"
#             ],
#             [
#                 "&str",
#                 "dst_name"
#             ],
#             [
#                 "&str",
#                 "edge_type_name"
#             ],
#             [
#                 "Option<&String>",
#                 ""
#             ]
#         ],
#         "return_type": "Result<EdgeT, String>"
#     },
#     "get_edge_type_counts": {
#         "arguments": [],
#         "return_type": "Result<Counter<EdgeTypeT, usize>, String>"
#     },
#     "get_edge_type_counts_hashmap": {
#         "arguments": [],
#         "return_type": "Result<HashMap<EdgeTypeT, usize>, String>"
#     },
#     "translate_edge_types": {
#         "arguments": [
#             [
#                 "&self",
#                 "edge_types"
#             ],
#             [
#                 "Vec<Option<String>>",
#                 ""
#             ]
#         ],
#         "return_type": "Result<Vec<Option<EdgeTypeT>>, String>"
#     },
#     "translate_node_types": {
#         "arguments": [
#             [
#                 "",
#                 "node_types"
#             ]
#         ],
#         "return_type": "Result<Vec<Option<NodeTypeT>>, String>"
#     },
#     "get_node_type_counts": {
#         "arguments": [],
#         "return_type": "Result<Counter<NodeTypeT, usize>, String>"
#     },
#     "get_node_type_counts_hashmap": {
#         "arguments": [],
#         "return_type": "Result<HashMap<EdgeTypeT, usize>, String>"
#     },
#     "has_edge_with_type_by_node_names": {
#         "arguments": [
#             [
#                 "&self",
#                 "src_name"
#             ],
#             [
#                 "&str",
#                 "dst_name"
#             ],
#             [
#                 "&str",
#                 "edge_type_name"
#             ],
#             [
#                 "Option<&String>",
#                 ""
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "has_node_with_type_by_name": {
#         "arguments": [
#             [
#                 "",
#                 "node_name"
#             ],
#             [
#                 "&str",
#                 "node_type_name"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "get_node_degree": {
#         "arguments": [
#             [
#                 "",
#                 "node"
#             ]
#         ],
#         "return_type": "NodeT"
#     },
#     "get_unchecked_edge_ids_range": {
#         "arguments": [
#             [
#                 "&self",
#                 "src"
#             ],
#             [
#                 "NodeT",
#                 "dst"
#             ],
#             [
#                 "NodeT",
#                 ""
#             ]
#         ],
#         "return_type": "impl Iterator<Item = EdgeT>"
#     },
#     "get_unchecked_destinations_range": {
#         "arguments": [
#             [
#                 "",
#                 "src"
#             ]
#         ],
#         "return_type": "impl Iterator<Item = EdgeT>"
#     },
#     "get_edge_ids": {
#         "arguments": [
#             [
#                 "",
#                 "src"
#             ],
#             [
#                 "NodeT",
#                 "dst"
#             ]
#         ],
#         "return_type": "Option<impl Iterator<Item = EdgeT>>"
#     },
#     "get_unchecked_link_edge_types": {
#         "arguments": [
#             [
#                 "&self",
#                 "src"
#             ],
#             [
#                 "NodeT",
#                 "dst"
#             ],
#             [
#                 "NodeT",
#                 ""
#             ]
#         ],
#         "return_type": "Option<Vec<Option<EdgeTypeT>>>"
#     },
#     "get_unchecked_link_weights": {
#         "arguments": [
#             [
#                 "",
#                 "src"
#             ],
#             [
#                 "NodeT",
#                 "dst"
#             ]
#         ],
#         "return_type": "Option<Vec<WeightT>>"
#     },
#     "is_node_trap": {
#         "arguments": [
#             [
#                 "",
#                 "node"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "is_edge_trap": {
#         "arguments": [
#             [
#                 "",
#                 "edge_id"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "get_nodes_iter": {
#         "arguments": [],
#         "return_type": "impl Iterator<Item = (NodeT, Option<Vec<NodeTypeT>>)> + '_"
#     },
#     "get_node_degrees_iter": {
#         "arguments": [],
#         "return_type": "impl Iterator<Item = NodeT> + '_"
#     },
#     "get_node_degrees_par_iter": {
#         "arguments": [],
#         "return_type": "impl ParallelIterator<Item = NodeT> + '_"
#     },
#     "get_nodes_names_iter": {
#         "arguments": [
#             [
#                 "&self",
#                 ""
#             ]
#         ],
#         "return_type": "impl Iterator<Item = (NodeT, String, Option<Vec<String>>)> + '_"
#     },
#     "get_edges_iter": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "Box<dyn Iterator<Item = (EdgeT, NodeT, NodeT)> + '_>"
#     },
#     "get_sources_iter": {
#         "arguments": [
#             [
#                 "",
#                 "directed"
#             ]
#         ],
#         "return_type": "impl Iterator<Item = NodeT> + '_"
#     },
#     "get_sources_par_iter": {
#         "arguments": [
#             [
#                 "",
#                 "directed"
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = NodeT> + '_"
#     },
#     "get_destinations_iter": {
#         "arguments": [
#             [
#                 "",
#                 "directed"
#             ]
#         ],
#         "return_type": "impl Iterator<Item = NodeT> + '_"
#     },
#     "get_destinations_par_iter": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = NodeT> + '_"
#     },
#     "get_edges_string_iter": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "impl Iterator<Item = (EdgeT, String, String)> + '_"
#     },
#     "get_edges_par_iter": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = (EdgeT, NodeT, NodeT)> + '_"
#     },
#     "get_edges_par_string_iter": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = (EdgeT, String, String)> + '_"
#     },
#     "get_edges_triples": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "impl Iterator<Item = (EdgeT, NodeT, NodeT, Option<EdgeTypeT>)> + '_"
#     },
#     "get_edges_string_triples": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "impl Iterator<Item = (EdgeT, String, String, Option<String>)> + '_"
#     },
#     "get_edges_par_string_triples": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = (EdgeT, String, String, Option<String>)> + '_"
#     },
#     "get_edges_par_string_quadruples": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = (EdgeT, String, String, Option<String>, Option<WeightT>)> + '_"
#     },
#     "get_edges_string_quadruples": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "impl Iterator<Item = (EdgeT, String, String, Option<String>, Option<WeightT>)> + '_"
#     },
#     "get_edges_par_triples": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = (EdgeT, NodeT, NodeT, Option<EdgeTypeT>)> + '_"
#     },
#     "get_edges_quadruples": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "impl Iterator<Item = (EdgeT, NodeT, NodeT, Option<EdgeTypeT>, Option<WeightT>)> + '_"
#     },
#     "get_edges_par_quadruples": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = (EdgeT, NodeT, NodeT, Option<EdgeTypeT>, Option<WeightT>)> + '_"
#     },
#     "get_edge_quadruple": {
#         "arguments": [
#             [
#                 "&self",
#                 "edge_id"
#             ],
#             [
#                 "EdgeT",
#                 ""
#             ]
#         ],
#         "return_type": "(NodeT, NodeT, Option<EdgeTypeT>, Option<WeightT>)"
#     },
#     "get_edge_triple": {
#         "arguments": [
#             [
#                 "",
#                 "edge_id"
#             ]
#         ],
#         "return_type": "(NodeT, NodeT, Option<EdgeTypeT>)"
#     },
#     "get_unique_edges_iter": {
#         "arguments": [
#             [
#                 "&self",
#                 "directed"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "Box<dyn Iterator<Item = (NodeT, NodeT)> + '_>"
#     },
#     "get_unique_sources_iter": {
#         "arguments": [],
#         "return_type": "impl Iterator<Item = NodeT> + '_"
#     },
#     "get_unique_sources_par_iter": {
#         "arguments": [],
#         "return_type": "impl ParallelIterator<Item = NodeT> + '_"
#     },
#     "from_sorted_csv<S: Into<String>>": {
#         "arguments": [
#             [
#                 "edge_file_reader",
#                 "EdgeFileReader"
#             ],
#             [
#                 "node_file_reader",
#                 "Option<NodeFileReader>"
#             ],
#             [
#                 "directed",
#                 "bool"
#             ],
#             [
#                 "directed_edge_list",
#                 "bool"
#             ],
#             [
#                 "edges_number",
#                 "EdgeT"
#             ],
#             [
#                 "nodes_number",
#                 "NodeT"
#             ],
#             [
#                 "name",
#                 "S"
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "from_unsorted_csv<S: Into<String>>": {
#         "arguments": [
#             [
#                 "edge_file_reader",
#                 "EdgeFileReader"
#             ],
#             [
#                 "node_file_reader",
#                 "Option<NodeFileReader>"
#             ],
#             [
#                 "directed",
#                 "bool"
#             ],
#             [
#                 "directed_edge_list",
#                 "bool"
#             ],
#             [
#                 "name",
#                 "S"
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "compute_hash": {
#         "arguments": [],
#         "return_type": "u64"
#     },
#     "sample_negatives": {
#         "arguments": [
#             [
#                 "&self",
#                 "random_state"
#             ],
#             [
#                 "EdgeT",
#                 "negatives_number"
#             ],
#             [
#                 "EdgeT",
#                 "seed_graph"
#             ],
#             [
#                 "Option<&Graph>",
#                 "only_from_same_component"
#             ],
#             [
#                 "bool",
#                 "verbose"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "connected_holdout": {
#         "arguments": [
#             [
#                 "&self",
#                 "random_state"
#             ],
#             [
#                 "EdgeT",
#                 "train_size"
#             ],
#             [
#                 "f64",
#                 "edge_types"
#             ],
#             [
#                 "Option<Vec<Option<String>>>",
#                 "include_all_edge_types"
#             ],
#             [
#                 "bool",
#                 "verbose"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "Result<(Graph, Graph), String>"
#     },
#     "random_holdout": {
#         "arguments": [
#             [
#                 "&self",
#                 "random_state"
#             ],
#             [
#                 "EdgeT",
#                 "train_size"
#             ],
#             [
#                 "f64",
#                 "include_all_edge_types"
#             ],
#             [
#                 "bool",
#                 "edge_types"
#             ],
#             [
#                 "Option<Vec<Option<String>>>",
#                 "min_number_overlaps"
#             ],
#             [
#                 "Option<EdgeT>",
#                 "verbose"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "Result<(Graph, Graph), String>"
#     },
#     "node_label_holdout": {
#         "arguments": [
#             [
#                 "&self",
#                 "train_size"
#             ],
#             [
#                 "f64",
#                 "use_stratification"
#             ],
#             [
#                 "bool",
#                 "random_state"
#             ],
#             [
#                 "EdgeT",
#                 ""
#             ]
#         ],
#         "return_type": "Result<(Graph, Graph), String>"
#     },
#     "edge_label_holdout": {
#         "arguments": [
#             [
#                 "&self",
#                 "train_size"
#             ],
#             [
#                 "f64",
#                 "use_stratification"
#             ],
#             [
#                 "bool",
#                 "random_state"
#             ],
#             [
#                 "EdgeT",
#                 ""
#             ]
#         ],
#         "return_type": "Result<(Graph, Graph), String>"
#     },
#     "random_subgraph": {
#         "arguments": [
#             [
#                 "&self",
#                 "random_state"
#             ],
#             [
#                 "usize",
#                 "nodes_number"
#             ],
#             [
#                 "NodeT",
#                 "verbose"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "kfold": {
#         "arguments": [
#             [
#                 "&self",
#                 "k"
#             ],
#             [
#                 "EdgeT",
#                 "k_index"
#             ],
#             [
#                 "u64",
#                 "edge_types"
#             ],
#             [
#                 "Option<Vec<Option<String>>>",
#                 "random_state"
#             ],
#             [
#                 "EdgeT",
#                 "verbose"
#             ],
#             [
#                 "bool",
#                 ""
#             ]
#         ],
#         "return_type": "Result<(Graph, Graph), String>"
#     }
# }

# %%
def filter_function(function_name, infos):
    return function_name in [
        "validate_weight",
        "parse_weight"
        
    ] or any(
        e in arg[1]
        for arg in infos["arguments"]
        for e in [
        ]
    )

# %%
structs = []
fields = []

template = """
#[derive(Arbitrary, Debug, Clone)]
struct %s {
# %s
}
"""

for function_name, info in functions_info.items():
    
    # Check if the function has parameters (other than self)
    if len(info["arguments"]) == 0:
        continue
        
    if filter_function(function_name, info):
        print("\n\nSkipping ", function_name)
        print(info["arguments"])
        continue
        
    
    struct_name = function_name.capitalize() + "_Params"
    
    fields.append("\t{function_name} : {struct_name},".format(
        function_name=function_name, 
        struct_name=struct_name,
    ))
        
          
    struct = template%(
        struct_name,
        "\n".join([
            "\t{field_name} : {field_type},".format(
                field_name=arg_name,
                field_type=arg_type,
            )
        for arg_name, arg_type in info["arguments"]
        ])
    )
    
    structs.append(struct)
    
    
fields.append( "\tfrom_vec: FromVecHarnessParams,")

harness = template%(
    "TheUltimateFuzzer",
    "\n".join(fields)
)
structs.append(harness)
    
result = "\n".join(structs)
# Out:
# Skipping  validate_weight
# [('weight', 'WeightT')]
#
#
# Skipping  parse_weight
# [('weight', 'String')]
#
#
# Skipping  from_sorted_csv<S: Into<String>>
# [('edge_file_reader', 'EdgeFileReader'), ('node_file_reader', 'Option<NodeFileReader>'), ('directed', 'bool'), ('directed_edge_list', 'bool'), ('edges_number', 'EdgeT'), ('nodes_number', 'NodeT'), ('name', 'S')]
#
#
# Skipping  from_unsorted_csv<S: Into<String>>
# [('edge_file_reader', 'EdgeFileReader'), ('node_file_reader', 'Option<NodeFileReader>'), ('directed', 'bool'), ('directed_edge_list', 'bool'), ('name', 'S')]

# %%
len(structs)
# Out:
# 127

# %%
def build_call(function_name, infos):
    if filter_function(function_name, infos):
        return ""
    
    args = ", ".join([
        f"data.{function_name}.{arg[0]}"
        for arg in infos["arguments"]
    ])
    
    result = f"\tgraph.{function_name}({args})"
    
    if infos["return_type"].startswith("Result"):
        result += "?"
    
    return result + ";"

# %%
harness = """
pub fn mega_test(data: TheUltimateFuzzer) -> Result<(), String> {
    let mut graph = graph::Graph::from_string_unsorted(
        data.from_vec.edges.into_iter(),
        data.from_vec.nodes.map(|ns| ns.into_iter()),
        data.from_vec.directed,
        data.from_vec.directed_edge_list,
        data.from_vec.name,
        data.from_vec.ignore_duplicated_nodes,
        data.from_vec.ignore_duplicated_edges,
        data.from_vec.verbose,
        data.from_vec.numeric_edge_types_ids,
        data.from_vec.numeric_node_ids,
        data.from_vec.numeric_edge_node_ids,
        data.from_vec.numeric_node_types_ids,
        data.from_vec.has_node_types,
        data.from_vec.has_edge_types,
        data.from_vec.has_weights,
    )?;
    
    
# %s

    Ok(())
}
"""%"\n".join(
    build_call(function_name, infos)
    for function_name, infos in functions_info.items()
)

# %%
with open("result.rs", "w") as f:
    f.write(setup + result + harness)
