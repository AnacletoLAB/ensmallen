# %%
import re
import glob
import json

# %%
path = "../../graph/src/*.rs"

# %%
def read_file(path):
    with open(path, "r") as f:
        return f.read()
    
def read_files(path):
    return [
        read_file(file)
        for file in glob.glob(path)
    ]

# %%
files = read_files(path)

# %%
functions = [
    x
    for file in files
    for x in re.findall(
        r"(pub\s+fn\s+[^\{]+?)\{", 
        "\n".join(
            re.findall(
                "impl\s+Graph\s+\{.+\}", 
                re.sub(r"\s+", r" ", file.replace("\n", ""))
            )
        ) or "", 
        re.MULTILINE
    )
]
len(functions)
# Out:
# 205

# %%
functions
# Out:
# ['pub fn are_nodes_remappable(&self, other: &Graph) -> bool ',
#  'pub fn remap(&self, other: &Graph, verbose: bool) -> Result<Graph, String> ',
#  'pub fn set_name(&mut self, name: String) ',
#  'pub fn extract_uniform_node(&self, node: NodeT, random_state: NodeT) -> NodeT ',
#  'pub fn extract_node( &self, node: NodeT, random_state: NodeT, walk_weights: &WalkWeights, min_edge_id: EdgeT, max_edge_id: EdgeT, destinations: &[NodeT], probabilistic_indices: &Option<Vec<u64>>, ) -> (NodeT, EdgeT) ',
#  'pub fn extract_edge( &self, src: NodeT, dst: NodeT, edge: EdgeT, random_state: NodeT, walk_weights: &WalkWeights, min_edge_id: EdgeT, max_edge_id: EdgeT, destinations: &[NodeT], previous_destinations: &[NodeT], probabilistic_indices: &Option<Vec<u64>>, ) -> (NodeT, EdgeT) ',
#  "pub fn random_walks_iter<'a>( &'a self, quantity: NodeT, parameters: &'a WalksParameters, ) -> Result<impl IndexedParallelIterator<Item = Vec<NodeT>> + 'a, String> ",
#  "pub fn complete_walks_iter<'a>( &'a self, parameters: &'a WalksParameters, ) -> Result<impl IndexedParallelIterator<Item = Vec<NodeT>> + 'a, String> ",
#  "pub fn walk_iter<'a>( &'a self, quantity: NodeT, to_node: impl Fn(NodeT) -> (NodeT, NodeT) + Sync + Send + 'a, parameters: &'a WalksParameters, ) -> Result<impl IndexedParallelIterator<Item = Vec<NodeT>> + 'a, String> ",
#  'pub fn single_walk( &self, node: NodeT, random_state: NodeT, parameters: &SingleWalkParameters, ) -> Vec<NodeT> ',
#  'pub fn new<S: Into<String>>( directed: bool, unique_self_loop_number: NodeT, self_loop_number: EdgeT, not_singleton_nodes_number: NodeT, singleton_nodes_with_self_loops_number: NodeT, unique_edges_number: EdgeT, edges: EliasFano, unique_sources: EliasFano, nodes: Vocabulary<NodeT>, node_bit_mask: EdgeT, node_bits: u8, edge_types: Option<EdgeTypeVocabulary>, name: S, weights: Option<Vec<WeightT>>, node_types: Option<NodeTypeVocabulary>, ) -> Graph ',
#  'pub fn overlaps(&self, other: &Graph) -> Result<bool, String> ',
#  'pub fn contains(&self, other: &Graph) -> Result<bool, String> ',
#  'pub fn get_name(&self) -> String ',
#  'pub fn get_traps_number(&self) -> EdgeT ',
#  'pub fn has_traps(&self) -> bool ',
#  'pub fn is_directed(&self) -> bool ',
#  'pub fn has_weights(&self) -> bool ',
#  'pub fn has_edge_types(&self) -> bool ',
#  'pub fn has_selfloops(&self) -> bool ',
#  'pub fn is_singleton(&self, node_id: NodeT) -> bool ',
#  'pub fn is_singleton_with_self_loops(&self, node_id: NodeT) -> bool ',
#  'pub fn is_singleton_by_nide_name(&self, node_name: &str) -> Result<bool, String> ',
#  'pub fn has_singletons(&self) -> bool ',
#  'pub fn has_singleton_nodes_with_self_loops_number(&self) -> bool ',
#  'pub fn get_sources(&self, directed: bool) -> Vec<NodeT> ',
#  'pub fn get_source_names(&self, directed: bool) -> Vec<String> ',
#  'pub fn get_destinations(&self, directed: bool) -> Vec<NodeT> ',
#  'pub fn get_destination_names(&self, directed: bool) -> Vec<String> ',
#  'pub fn get_node_names(&self) -> Vec<String> ',
#  'pub fn get_nodes(&self) -> Vec<NodeT> ',
#  'pub fn get_top_k_central_nodes(&self, k: NodeT) -> Vec<NodeT> ',
#  'pub fn get_top_k_central_node_names(&self, k: NodeT) -> Vec<String> ',
#  'pub fn get_edge_types(&self) -> Option<Vec<Option<EdgeTypeT>>> ',
#  'pub fn get_edge_type_name(&self, edge_type_id: EdgeTypeT) -> Result<&String, String> ',
#  'pub fn get_edge_type_names(&self) -> Option<Vec<String>> ',
#  'pub fn get_node_types(&self) -> Option<Vec<Option<Vec<NodeTypeT>>>> ',
#  'pub fn translate_node_type_id(&self, node_type_id: NodeTypeT) -> Result<&String, String> ',
#  'pub fn translate_node_type_id_vector( &self, node_type_id: Vec<NodeTypeT>, ) -> Result<Vec<String>, String> ',
#  'pub fn get_weights(&self) -> Option<Vec<WeightT>> ',
#  'pub fn get_node_type_names(&self) -> Option<Vec<String>> ',
#  'pub fn get_unique_directed_edges_number(&self) -> EdgeT ',
#  'pub fn get_max_encodable_edge_number(&self) -> EdgeT ',
#  'pub fn get_nodes_mapping(&self) -> HashMap<String, NodeT> ',
#  'pub fn get_edges(&self, directed: bool) -> Vec<Vec<NodeT>> ',
#  'pub fn get_edge_names(&self, directed: bool) -> Vec<(String, String)> ',
#  'pub fn get_unchecked_edge_type(&self, edge_id: EdgeT) -> Option<EdgeTypeT> ',
#  'pub fn get_unchecked_edge_weight(&self, edge_id: EdgeT) -> Option<WeightT> ',
#  'pub fn get_unchecked_node_type(&self, node_id: NodeT) -> Option<Vec<NodeTypeT>> ',
#  'pub fn get_node_type_id_by_node_id(&self, node_id: NodeT) -> Result<Option<Vec<NodeTypeT>>, String> ',
#  'pub fn get_edge_type(&self, edge_id: EdgeT) -> Result<Option<EdgeTypeT>, String> ',
#  'pub fn get_node_type_name(&self, node_id: NodeT) -> Result<Option<Vec<String>>, String> ',
#  'pub fn get_edge_type_name_by_edge_id(&self, edge_id: EdgeT) -> Option<String> ',
#  'pub fn get_node_name(&self, node_id: NodeT) -> Result<String, String> ',
#  'pub fn get_node_id(&self, node_name: &str) -> Result<NodeT, String> ',
#  'pub fn get_node_type_id_by_node_name(&self, node_name: &str) -> Result<Option<Vec<NodeTypeT>>, String> ',
#  'pub fn get_node_type_name_by_node_name(&self, node_name: &str) -> Result<Option<Vec<String>>, String> ',
#  'pub fn has_node_by_name(&self, node_name: &str) -> bool ',
#  'pub fn get_unchecked_node_id(&self, node_name: &str) -> NodeT ',
#  'pub fn get_unchecked_edge_type_id(&self, edge_type: Option<&str>) -> Option<EdgeTypeT> ',
#  'pub fn get_edge_weight(&self, edge_id: EdgeT) -> Option<WeightT> ',
#  'pub fn has_node_types(&self) -> bool ',
#  'pub fn has_multilabel_node_types(&self) -> bool ',
#  'pub fn get_unknown_node_types_number(&self) -> NodeT ',
#  'pub fn get_minimum_node_types_number(&self) -> NodeT ',
#  'pub fn has_unknown_node_types(&self) -> bool ',
#  'pub fn get_unknown_edge_types_number(&self) -> EdgeT ',
#  'pub fn get_minimum_edge_types_number(&self) -> EdgeT ',
#  'pub fn has_unknown_edge_types(&self) -> bool ',
#  'pub fn get_nodes_number(&self) -> NodeT ',
#  'pub fn get_node_components_vector(&self, verbose: bool) -> Vec<NodeT> ',
#  'pub fn get_directed_edges_number(&self) -> EdgeT ',
#  'pub fn get_edge_types_number(&self) -> EdgeTypeT ',
#  'pub fn get_node_types_number(&self) -> NodeTypeT ',
#  'pub fn get_node_degrees(&self) -> Vec<NodeT> ',
#  'pub fn get_not_singletons(&self) -> Vec<NodeT> ',
#  'pub fn get_dense_node_mapping(&self) -> HashMap<NodeT, NodeT> ',
#  'pub fn get_unchecked_edge_count_by_edge_type(&self, edge_type: Option<EdgeTypeT>) -> EdgeT ',
#  'pub fn get_edge_count_by_edge_type(&self, edge_type: Option<EdgeTypeT>) -> Result<EdgeT, String> ',
#  'pub fn get_edge_type_id(&self, edge_type_name: Option<&str>) -> Result<Option<EdgeTypeT>, String> ',
#  'pub fn get_edge_count_by_edge_type_name(&self, edge_type: Option<&str>) -> Result<EdgeT, String> ',
#  'pub fn get_unchecked_node_count_by_node_type(&self, node_type: NodeTypeT) -> NodeT ',
#  'pub fn get_node_type_id(&self, node_type_name: &str) -> Result<NodeTypeT, String> ',
#  'pub fn get_node_count_by_node_type(&self, node_type: NodeTypeT) -> Result<NodeT, String> ',
#  'pub fn get_node_count_by_node_type_name(&self, node_type: &str) -> Result<NodeT, String> ',
#  'pub fn is_multigraph(&self) -> bool ',
#  'pub fn get_multigraph_edges_number(&self) -> EdgeT ',
#  'pub fn get_outbounds(&self) -> Vec<EdgeT> ',
#  'pub fn get_destination(&self, edge_id: EdgeT) -> NodeT ',
#  "pub fn get_destinations_range( &self, min_edge_id: EdgeT, max_edge_id: EdgeT, ) -> impl Iterator<Item = NodeT> + '_ ",
#  "pub fn get_neighbours_iter(&self, src: NodeT) -> impl Iterator<Item = NodeT> + '_ ",
#  'pub fn get_unique_sources_number(&self) -> NodeT ',
#  'pub fn get_source_nodes_number(&self) -> NodeT ',
#  'pub fn get_unchecked_edge_id( &self, src: NodeT, dst: NodeT, edge_type: Option<EdgeTypeT>, ) -> EdgeT ',
#  'pub fn get_edge_id( &self, src: NodeT, dst: NodeT, edge_type: Option<EdgeTypeT>, ) -> Result<EdgeT, String> ',
#  'pub fn has_edge(&self, src: NodeT, dst: NodeT) -> bool ',
#  'pub fn has_edge_with_type(&self, src: NodeT, dst: NodeT, edge_type: Option<EdgeTypeT>) -> bool ',
#  'pub fn get_edge_id_by_node_names( &self, src_name: &str, dst_name: &str ) -> Result<EdgeT, String> ',
#  'pub fn has_edge_by_node_names( &self, src_name: &str, dst_name: &str ) -> bool ',
#  'pub fn get_edge_id_with_type_by_node_names( &self, src_name: &str, dst_name: &str, edge_type_name: Option<&String>, ) -> Result<EdgeT, String> ',
#  'pub fn get_edge_type_counts(&self) -> Result<Counter<EdgeTypeT, usize>, String> ',
#  'pub fn get_edge_type_counts_hashmap(&self) -> Result<HashMap<EdgeTypeT, usize>, String> ',
#  'pub fn translate_edge_types( &self, edge_types: Vec<Option<String>>, ) -> Result<Vec<Option<EdgeTypeT>>, String> ',
#  'pub fn translate_node_types(&self, node_types: Vec<Option<String>>) -> Result<Vec<Option<NodeTypeT>>, String> ',
#  'pub fn get_node_type_counts(&self) -> Result<Counter<NodeTypeT, usize>, String> ',
#  'pub fn get_node_type_counts_hashmap(&self) -> Result<HashMap<EdgeTypeT, usize>, String> ',
#  'pub fn has_edge_with_type_by_node_names( &self, src_name: &str, dst_name: &str, edge_type_name: Option<&String>, ) -> bool ',
#  'pub fn has_node_with_type_by_name(&self, node_name: &str, node_type_name: Option<Vec<String>>) -> bool ',
#  'pub fn get_node_degree(&self, node: NodeT) -> NodeT ',
#  'pub fn get_unchecked_edge_ids_range( &self, src: NodeT, dst: NodeT, ) -> impl Iterator<Item = EdgeT> ',
#  'pub fn get_unchecked_destinations_range(&self, src: NodeT) -> impl Iterator<Item = EdgeT> ',
#  'pub fn get_edge_ids(&self, src: NodeT, dst: NodeT) -> Option<impl Iterator<Item = EdgeT>> ',
#  'pub fn get_unchecked_link_edge_types( &self, src: NodeT, dst: NodeT, ) -> Option<Vec<Option<EdgeTypeT>>> ',
#  'pub fn get_unchecked_link_weights(&self, src: NodeT, dst: NodeT) -> Option<Vec<WeightT>> ',
#  'pub fn is_node_trap(&self, node: NodeT) -> bool ',
#  'pub fn is_edge_trap(&self, edge_id: EdgeT) -> bool ',
#  'pub fn remove( &self, allow_nodes_set: Option<HashSet<String>>, deny_nodes_set: Option<HashSet<String>>, allow_node_types_set: Option<HashSet<String>>, deny_node_types_set: Option<HashSet<String>>, allow_edge_set: Option<HashSet<EdgeT>>, deny_edge_set: Option<HashSet<EdgeT>>, allow_edge_types_set: Option<HashSet<String>>, deny_edge_types_set: Option<HashSet<String>>, weights: bool, node_types: bool, edge_types: bool, singletons: bool, selfloops: bool, verbose: bool, ) -> Result<Graph, String> ',
#  'pub fn remove_components( &self, node_names: Option<Vec<String>>, node_types: Option<Vec<Option<String>>>, edge_types: Option<Vec<Option<String>>>, minimum_component_size: Option<NodeT>, top_k_components: Option<NodeT>, verbose: bool, ) -> Result<Graph, String> ',
#  'pub fn set_all_edge_types<S: Into<String>>(mut self, edge_type: S) -> Graph ',
#  'pub fn set_all_node_types<S: Into<String>>(mut self, node_type: S) -> Graph ',
#  'pub fn enable( &mut self, vector_sources: bool, vector_destinations: bool, vector_outbounds: bool, cache_size: Option<f64>, ) -> Result<(), String> ',
#  'pub fn disable_all(&mut self) ',
#  "pub fn kruskal<'a>( &self, edges: impl Iterator<Item = (NodeT, NodeT)> + 'a, ) -> (HashSet<(NodeT, NodeT)>, Vec<NodeT>, NodeT, NodeT, NodeT) ",
#  'pub fn random_spanning_arborescence_kruskal( &self, random_state: EdgeT, unwanted_edge_types: &Option<HashSet<Option<EdgeTypeT>>>, verbose: bool, ) -> (HashSet<(NodeT, NodeT)>, Vec<NodeT>, NodeT, NodeT, NodeT) ',
#  'pub fn spanning_arborescence_kruskal( &self, verbose: bool, ) -> (HashSet<(NodeT, NodeT)>, Vec<NodeT>, NodeT, NodeT, NodeT) ',
#  "pub fn spanning_arborescence( &self, verbose: bool, ) -> Result<(usize, impl Iterator<Item = (NodeT, NodeT)> + '_), String> ",
#  'pub fn connected_components( &self, verbose: bool, ) -> Result<(Vec<NodeT>, NodeT, NodeT, NodeT), String> ',
#  "pub fn get_nodes_iter(&self) -> impl Iterator<Item = (NodeT, Option<Vec<NodeTypeT>>)> + '_ ",
#  "pub fn get_node_degrees_iter(&self) -> impl Iterator<Item = NodeT> + '_ ",
#  "pub fn get_node_degrees_par_iter(&self) -> impl ParallelIterator<Item = NodeT> + '_ ",
#  "pub fn get_nodes_names_iter( &self, ) -> impl Iterator<Item = (NodeT, String, Option<Vec<String>>)> + '_ ",
#  "pub fn get_edges_iter( &self, directed: bool, ) -> Box<dyn Iterator<Item = (EdgeT, NodeT, NodeT)> + '_> ",
#  "pub fn get_sources_iter(&self, directed: bool) -> impl Iterator<Item = NodeT> + '_ ",
#  "pub fn get_sources_par_iter(&self, directed: bool) -> impl ParallelIterator<Item = NodeT> + '_ ",
#  "pub fn get_destinations_iter(&self, directed: bool) -> impl Iterator<Item = NodeT> + '_ ",
#  "pub fn get_destinations_par_iter( &self, directed: bool, ) -> impl ParallelIterator<Item = NodeT> + '_ ",
#  "pub fn get_edges_string_iter( &self, directed: bool, ) -> impl Iterator<Item = (EdgeT, String, String)> + '_ ",
#  "pub fn get_edges_par_iter( &self, directed: bool, ) -> impl ParallelIterator<Item = (EdgeT, NodeT, NodeT)> + '_ ",
#  "pub fn get_edges_par_string_iter( &self, directed: bool, ) -> impl ParallelIterator<Item = (EdgeT, String, String)> + '_ ",
#  "pub fn get_edges_triples( &self, directed: bool, ) -> impl Iterator<Item = (EdgeT, NodeT, NodeT, Option<EdgeTypeT>)> + '_ ",
#  "pub fn get_edges_string_triples( &self, directed: bool, ) -> impl Iterator<Item = (EdgeT, String, String, Option<String>)> + '_ ",
#  "pub fn get_edges_par_string_triples( &self, directed: bool, ) -> impl ParallelIterator<Item = (EdgeT, String, String, Option<String>)> + '_ ",
#  "pub fn get_edges_par_string_quadruples( &self, directed: bool, ) -> impl ParallelIterator<Item = (EdgeT, String, String, Option<String>, Option<WeightT>)> + '_ ",
#  "pub fn get_edges_string_quadruples( &self, directed: bool, ) -> impl Iterator<Item = (EdgeT, String, String, Option<String>, Option<WeightT>)> + '_ ",
#  "pub fn get_edges_par_triples( &self, directed: bool, ) -> impl ParallelIterator<Item = (EdgeT, NodeT, NodeT, Option<EdgeTypeT>)> + '_ ",
#  "pub fn get_edges_quadruples( &self, directed: bool, ) -> impl Iterator<Item = (EdgeT, NodeT, NodeT, Option<EdgeTypeT>, Option<WeightT>)> + '_ ",
#  "pub fn get_edges_par_quadruples( &self, directed: bool, ) -> impl ParallelIterator<Item = (EdgeT, NodeT, NodeT, Option<EdgeTypeT>, Option<WeightT>)> + '_ ",
#  'pub fn get_edge_quadruple( &self, edge_id: EdgeT, ) -> (NodeT, NodeT, Option<EdgeTypeT>, Option<WeightT>) ',
#  'pub fn get_edge_triple(&self, edge_id: EdgeT) -> (NodeT, NodeT, Option<EdgeTypeT>) ',
#  "pub fn get_unique_edges_iter( &self, directed: bool, ) -> Box<dyn Iterator<Item = (NodeT, NodeT)> + '_> ",
#  "pub fn get_unique_sources_iter(&self) -> impl Iterator<Item = NodeT> + '_ ",
#  "pub fn get_unique_sources_par_iter(&self) -> impl ParallelIterator<Item = NodeT> + '_ ",
#  'pub fn strongly_connected_components(&self) -> Vec<HashSet<NodeT>> ',
#  'pub fn compute_hash(&self) -> u64 ',
#  'pub fn degrees_product(&self, one: NodeT, two: NodeT) -> Result<usize, String> ',
#  'pub fn jaccard_index(&self, one: NodeT, two: NodeT) -> Result<f64, String> ',
#  'pub fn adamic_adar_index(&self, one: NodeT, two: NodeT) -> Result<f64, String> ',
#  'pub fn resource_allocation_index(&self, one: NodeT, two: NodeT) -> Result<f64, String> ',
#  'pub fn traps_rate(&self) -> f64 ',
#  'pub fn degrees_mean(&self) -> f64 ',
#  'pub fn get_undirected_edges_number(&self) -> EdgeT ',
#  'pub fn get_unique_undirected_edges_number(&self) -> EdgeT ',
#  'pub fn get_edges_number(&self) -> EdgeT ',
#  'pub fn get_unique_edges_number(&self) -> EdgeT ',
#  'pub fn degrees_median(&self) -> NodeT ',
#  'pub fn max_degree(&self) -> NodeT ',
#  'pub fn min_degree(&self) -> NodeT ',
#  'pub fn degrees_mode(&self) -> NodeT ',
#  'pub fn get_self_loop_number(&self) -> EdgeT ',
#  'pub fn get_unique_self_loop_number(&self) -> NodeT ',
#  'pub fn get_self_loop_rate(&self) -> f64 ',
#  'pub fn connected_components_number(&self, verbose: bool) -> (NodeT, NodeT, NodeT) ',
#  'pub fn get_singleton_nodes_number(&self) -> NodeT ',
#  'pub fn get_singleton_nodes_with_self_loops_number(&self) -> NodeT ',
#  'pub fn get_not_singleton_nodes_number(&self) -> NodeT ',
#  'pub fn density(&self) -> f64 ',
#  'pub fn report(&self) -> DefaultHashMap<&str, String> ',
#  'pub fn overlap_textual_report(&self, other: &Graph, verbose: bool) -> Result<String, String> ',
#  'pub fn textual_report(&self, verbose: bool) -> Result<String, String> ',
#  'pub fn get_bipartite_edges( &self, removed_existing_edges: Option<bool>, first_nodes_set: Option<HashSet<String>>, second_nodes_set: Option<HashSet<String>>, first_node_types_set: Option<HashSet<String>>, second_node_types_set: Option<HashSet<String>>, ) -> Result<Vec<Vec<NodeT>>, String> ',
#  'pub fn get_bipartite_edge_names( &self, removed_existing_edges: Option<bool>, first_nodes_set: Option<HashSet<String>>, second_nodes_set: Option<HashSet<String>>, first_node_types_set: Option<HashSet<String>>, second_node_types_set: Option<HashSet<String>>, ) -> Result<Vec<Vec<String>>, String> ',
#  'pub fn get_star_edges( &self, central_node: String, removed_existing_edges: Option<bool>, star_points_nodes_set: Option<HashSet<String>>, star_points_node_types_set: Option<HashSet<String>>, ) -> Result<Vec<Vec<NodeT>>, String> ',
#  'pub fn get_star_edge_names( &self, central_node: String, removed_existing_edges: Option<bool>, star_points_nodes_set: Option<HashSet<String>>, star_points_node_types_set: Option<HashSet<String>>, ) -> Result<Vec<Vec<String>>, String> ',
#  'pub fn get_clique_edges( &self, directed: Option<bool>, allow_self_loops: Option<bool>, removed_existing_edges: Option<bool>, allow_node_type_set: Option<HashSet<String>>, allow_node_set: Option<HashSet<String>>, ) -> Vec<Vec<NodeT>> ',
#  'pub fn get_clique_edge_names( &self, directed: Option<bool>, allow_self_loops: Option<bool>, removed_existing_edges: Option<bool>, allow_node_type_set: Option<HashSet<String>>, allow_node_set: Option<HashSet<String>>, ) -> Vec<Vec<String>> ',
#  "pub fn node2vec<'a>( &'a self, walk_parameters: &'a WalksParameters, quantity: NodeT, window_size: usize, ) -> Result<impl ParallelIterator<Item = (Vec<NodeT>, NodeT)> + 'a, String> ",
#  'pub fn cooccurence_matrix( &self, walks_parameters: &WalksParameters, window_size: usize, verbose: bool, ) -> Result<(Words, Words, Frequencies), String> ',
#  "pub fn link_prediction_degrees<'a>( &'a self, idx: u64, batch_size: usize, normalize: bool, negative_samples: f64, avoid_false_negatives: bool, maximal_sampling_attempts: usize, graph_to_avoid: &'a Option<&Graph>, ) -> Result<impl ParallelIterator<Item = (usize, f64, f64, bool)> + 'a, String> ",
#  "pub fn link_prediction_ids<'a>( &'a self, idx: u64, batch_size: usize, negative_samples: f64, avoid_false_negatives: bool, maximal_sampling_attempts: usize, graph_to_avoid: &'a Option<&Graph>, ) -> Result<impl ParallelIterator<Item = (usize, NodeT, NodeT, bool)> + 'a, String> ",
#  'pub fn validate_weight(weight: WeightT) -> Result<WeightT, String> ',
#  'pub fn parse_weight(weight: String) -> Result<WeightT, String> ',
#  'pub fn from_sorted_csv<S: Into<String>>( edge_file_reader: EdgeFileReader, node_file_reader: Option<NodeFileReader>, directed: bool, directed_edge_list: bool, edges_number: usize, nodes_number: NodeT, name: S, ) -> Result<Graph, String> ',
#  'pub fn from_unsorted_csv<S: Into<String>>( edge_file_reader: EdgeFileReader, node_file_reader: Option<NodeFileReader>, directed: bool, directed_edge_list: bool, name: S, ) -> Result<Graph, String> ',
#  'pub fn sample_negatives( &self, mut random_state: EdgeT, negatives_number: EdgeT, seed_graph: Option<&Graph>, only_from_same_component: bool, verbose: bool, ) -> Result<Graph, String> ',
#  'pub fn connected_holdout( &self, random_state: EdgeT, train_size: f64, edge_types: Option<Vec<Option<String>>>, include_all_edge_types: bool, verbose: bool, ) -> Result<(Graph, Graph), String> ',
#  'pub fn random_holdout( &self, random_state: EdgeT, train_size: f64, include_all_edge_types: bool, edge_types: Option<Vec<Option<String>>>, min_number_overlaps: Option<EdgeT>, verbose: bool, ) -> Result<(Graph, Graph), String> ',
#  'pub fn node_label_holdout( &self, train_size: f64, use_stratification: bool, random_state: EdgeT, ) -> Result<(Graph, Graph), String> ',
#  'pub fn edge_label_holdout( &self, train_size: f64, use_stratification: bool, random_state: EdgeT, ) -> Result<(Graph, Graph), String> ',
#  'pub fn random_subgraph( &self, random_state: usize, nodes_number: NodeT, verbose: bool, ) -> Result<Graph, String> ',
#  'pub fn kfold( &self, k: EdgeT, k_index: u64, edge_types: Option<Vec<Option<String>>>, random_state: EdgeT, verbose: bool, ) -> Result<(Graph, Graph), String> ',
#  'pub fn filter( &self, node_names: Option<Vec<String>>, node_types: Option<Vec<Option<String>>>, edge_types: Option<Vec<Option<String>>>, min_weight: Option<WeightT>, max_weight: Option<WeightT>, verbose: bool, ) -> Result<Graph, String> ',
#  "pub fn get_filtered_neighbours_range( &self, src: NodeT, node_names: Option<Vec<String>>, node_types: Option<Vec<Option<String>>>, edge_types: Option<Vec<Option<String>>>, min_weight: Option<WeightT>, max_weight: Option<WeightT>, ) -> Result<impl Iterator<Item = NodeT> + '_, String> ",
#  'pub fn from_string_unsorted<S: Into<String>>( edges_iterator: impl Iterator<Item = Result<StringQuadruple, String>>, nodes_iterator: Option<impl Iterator<Item = Result<(String, Option<Vec<String>>), String>>>, directed: bool, directed_edge_list: bool, name: S, ignore_duplicated_nodes: bool, ignore_duplicated_edges: bool, verbose: bool, numeric_edge_type_ids: bool, numeric_node_ids: bool, numeric_edge_node_ids: bool, numeric_node_types_ids: bool, has_node_types: bool, has_edge_types: bool, has_weights: bool, ) -> Result<Graph, String> ',
#  'pub fn from_integer_unsorted( edges_iterator: impl Iterator< Item = Result<(NodeT, NodeT, Option<NodeTypeT>, Option<WeightT>), String>, >, nodes: Vocabulary<NodeT>, node_types: Option<NodeTypeVocabulary>, edge_types_vocabulary: Option<Vocabulary<EdgeTypeT>>, directed: bool, name: String, ignore_duplicated_edges: bool, has_edge_types: bool, has_weights: bool, verbose: bool, ) -> Result<Graph, String> ',
#  'pub fn from_string_sorted<S: Into<String>>( edges_iterator: impl Iterator<Item = Result<StringQuadruple, String>>, nodes_iterator: Option<impl Iterator<Item = Result<(String, Option<Vec<String>>), String>>>, directed: bool, directed_edge_list: bool, automatic_directed_edge_list: bool, ignore_duplicated_nodes: bool, ignore_duplicated_edges: bool, edges_number: usize, nodes_number: NodeT, numeric_edge_type_ids: bool, numeric_node_ids: bool, numeric_edge_node_ids: bool, numeric_node_types_ids: bool, has_node_types: bool, has_edge_types: bool, has_weights: bool, name: S, ) -> Result<Graph, String> ']

# %%
from lark import Lark, Transformer, Token, Tree

# %%
dont_care = lambda self, args: args[0]

class FunctionToJson(Transformer):
    def type(self, args):        
        arg = args[0]
        if isinstance(arg, Token):
            if arg.type == "IDENTIFIER":
                return arg.value.strip()
        if isinstance(arg, str):
            return arg
                
        return args
    
    start = dont_care
    function_return_type = dont_care
    lifetime_or_type = dont_care
        
    
    def type_with_modifiers(self, args):
        output = ""
        for token in args:
            if isinstance(token, Token):
                output += token.value
                continue
                
            if isinstance(token, str):
                output += token
                continue
                
            print("Warning, token %s not parsed"%token)
        return output
    
    def life_time(self, args):
        return "'" + args[0].value + " "
    
    def self_param(self, args):
        output = ""
        for token in args:
            if isinstance(token, Token):
                output += token.value
                continue
                
            if isinstance(token, str):
                output += token
                continue
                
        return {"self":output}
    
    def bound_type(self, args):
        return "{}<{}>".format(
            args[0].value.strip(),
            ", ".join(args[1:])
        )
    def assign_type(self, args):
        return args[0] + " = " + args[1]
    
    def slice_type(self, args):
        return "[" + args[0] + "]"
    
    def function_param(self, args):
        return {args[0].value.strip() : args[1]}
    
    def function_parameters(self, args):
        return {
            k: v 
            for arg in args
            for k, v in arg.items()
        }
    
    def tuple_type(self, args):
        return "(" + ", ".join(args) + ")"
    
    def impl_type(self,args):
        return "impl " + args[0]
    
    def summed_type(self, args):
        return " + ".join(args)
            
    def function_type(self, args):
        return "Fn(%s) -> %s"%tuple(args)
    
    def generic_params(self, args):
        return "<" + ", ".join(args) + ">"
    
    def function_name(self, args):
        if len(args) == 1:
            return args[0].value
        
        return args[0].value + args[1]
    
    def function(self, args):
        if len(args) > 3:
            returns = args[3]
        else:
            returns = None
        return {
            "function_name":args[1],
            "params":args[2],
            "return":returns
        }

# %%
with open("./rust_functions_grammar.lark") as f:
    grammar = f.read()
    
parser = Lark(grammar)

for function in functions[:10]:
    print(function)
    tree = parser.parse(function)
    # print(tree.pretty())
    print(json.dumps(FunctionToJson().transform(tree), indent=4))
# Out:
# pub fn are_nodes_remappable(&self, other: &Graph) -> bool
# {
#     "function_name": " are_nodes_remappable",
#     "params": {
#         "self": "&self",
#         "other": "&Graph"
#     },
#     "return": "bool"
# }
# pub fn remap(&self, other: &Graph, verbose: bool) -> Result<Graph, String>
# {
#     "function_name": " remap",
#     "params": {
#         "self": "&self",
#         "other": "&Graph",
#         "verbose": "bool"
#     },
#     "return": "Result<Graph, String>"
# }
# pub fn set_name(&mut self, name: String)
# {
#     "function_name": " set_name",
#     "params": {
#         "self": "&mutself",
#         "name": "String"
#     },
#     "return": null
# }
# pub fn extract_uniform_node(&self, node: NodeT, random_state: NodeT) -> NodeT
# {
#     "function_name": " extract_uniform_node",
#     "params": {
#         "self": "&self",
#         "node": "NodeT",
#         "random_state": "NodeT"
#     },
#     "return": "NodeT"
# }
# pub fn extract_node( &self, node: NodeT, random_state: NodeT, walk_weights: &WalkWeights, min_edge_id: EdgeT, max_edge_id: EdgeT, destinations: &[NodeT], probabilistic_indices: &Option<Vec<u64>>, ) -> (NodeT, EdgeT)
# {
#     "function_name": " extract_node",
#     "params": {
#         "self": "&self",
#         "node": "NodeT",
#         "random_state": "NodeT",
#         "walk_weights": "&WalkWeights",
#         "min_edge_id": "EdgeT",
#         "max_edge_id": "EdgeT",
#         "destinations": "&[NodeT]",
#         "probabilistic_indices": "&Option<Vec<u64>>"
#     },
#     "return": "(NodeT, EdgeT)"
# }
# pub fn extract_edge( &self, src: NodeT, dst: NodeT, edge: EdgeT, random_state: NodeT, walk_weights: &WalkWeights, min_edge_id: EdgeT, max_edge_id: EdgeT, destinations: &[NodeT], previous_destinations: &[NodeT], probabilistic_indices: &Option<Vec<u64>>, ) -> (NodeT, EdgeT)
# {
#     "function_name": " extract_edge",
#     "params": {
#         "self": "&self",
#         "src": "NodeT",
#         "dst": "NodeT",
#         "edge": "EdgeT",
#         "random_state": "NodeT",
#         "walk_weights": "&WalkWeights",
#         "min_edge_id": "EdgeT",
#         "max_edge_id": "EdgeT",
#         "destinations": "&[NodeT]",
#         "previous_destinations": "&[NodeT]",
#         "probabilistic_indices": "&Option<Vec<u64>>"
#     },
#     "return": "(NodeT, EdgeT)"
# }
# pub fn random_walks_iter<'a>( &'a self, quantity: NodeT, parameters: &'a WalksParameters, ) -> Result<impl IndexedParallelIterator<Item = Vec<NodeT>> + 'a, String>
# {
#     "function_name": " random_walks_iter<'a >",
#     "params": {
#         "self": "&'a self",
#         "quantity": "NodeT",
#         "parameters": "&'a WalksParameters"
#     },
#     "return": "Result<impl IndexedParallelIterator<Item  = Vec<NodeT>> + 'a , String>"
# }
# pub fn complete_walks_iter<'a>( &'a self, parameters: &'a WalksParameters, ) -> Result<impl IndexedParallelIterator<Item = Vec<NodeT>> + 'a, String>
# {
#     "function_name": " complete_walks_iter<'a >",
#     "params": {
#         "self": "&'a self",
#         "parameters": "&'a WalksParameters"
#     },
#     "return": "Result<impl IndexedParallelIterator<Item  = Vec<NodeT>> + 'a , String>"
# }
# pub fn walk_iter<'a>( &'a self, quantity: NodeT, to_node: impl Fn(NodeT) -> (NodeT, NodeT) + Sync + Send + 'a, parameters: &'a WalksParameters, ) -> Result<impl IndexedParallelIterator<Item = Vec<NodeT>> + 'a, String>
# {
#     "function_name": " walk_iter<'a >",
#     "params": {
#         "self": "&'a self",
#         "quantity": "NodeT",
#         "to_node": "impl Fn(NodeT) -> (NodeT, NodeT) + Sync + Send + 'a ",
#         "parameters": "&'a WalksParameters"
#     },
#     "return": "Result<impl IndexedParallelIterator<Item  = Vec<NodeT>> + 'a , String>"
# }
# pub fn single_walk( &self, node: NodeT, random_state: NodeT, parameters: &SingleWalkParameters, ) -> Vec<NodeT>
# {
#     "function_name": " single_walk",
#     "params": {
#         "self": "&self",
#         "node": "NodeT",
#         "random_state": "NodeT",
#         "parameters": "&SingleWalkParameters"
#     },
#     "return": "Vec<NodeT>"
# }
