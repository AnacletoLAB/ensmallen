# %%
import re
import glob
import json

# %%
path = "../../graph/src/*.rs"

# %%
setup = """
use super::*;
use arbitrary::Arbitrary;
use std::collections::HashSet;

"""

# %%
def read_file(path):
    with open(path, "r") as f:
        return f.read()
    
def read_files(path):
    return [
        read_file(file)
        for file in glob.glob(path)
    ]

# %%
files = read_files(path)

# %%
def remove_prefix(text, prefix):
    if text.startswith(prefix):
        return text[len(prefix):]
    return text  # or whatever

def parse_arguments(arguments):
    flat = [
        remove_prefix(x.strip(), "mut").strip()
        for comb in arguments.split(":")
        for x in comb.rsplit(",", 1)
    ]
    
    return [
            (arg_name, arg_type)
            for (arg_name, arg_type) in zip(flat[::2], flat[1::2])
    ]

# %%
#  r"pub\s+fn\s+([^\(\{]+?)\((self|&\s*self|&mut\s+self|&'.\s+self)?([^\)\{]+?)\)\s*(:?->\s*([^\{]+?))\{"

# %%
functions = [
    x
    for file in files
    for x in re.findall(
        r"pub\s+fn\s+([^\{]+?)\{", 
        "\n".join(
            re.findall(
                "impl\s+Graph\s+\{.+\}", 
                file.replace("\n", "")
            )
        ) or "", 
        re.MULTILINE
    )
]
len(functions)
# Out:
# 196

# %%
functions_info = {
    function_name:{
        "arguments":parse_arguments(args),
        "return_type":return_type.strip(),
    }
    for function in functions
    for function_name, _, _, args, return_type in re.findall(r"(\w+)(<.+?>)?\(\s*(self|&\s*self|&\s*mut\s*self)\s*,\s*(.+)\s*\)\s*->\s*(.+)\s*", function)
}

# %%
print(json.dumps(functions_info, indent=4))
# Out:
# {
#     "random_spanning_arborescence_kruskal": {
#         "arguments": [
#             [
#                 "random_state",
#                 "EdgeT"
#             ],
#             [
#                 "unwanted_edge_types",
#                 "&Option<HashSet<Option<EdgeTypeT>>>"
#             ],
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "(HashSet<(NodeT, NodeT)>, Vec<NodeT>, NodeT, NodeT, NodeT)"
#     },
#     "spanning_arborescence_kruskal": {
#         "arguments": [
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "(HashSet<(NodeT, NodeT)>, Vec<NodeT>, NodeT, NodeT, NodeT)"
#     },
#     "spanning_arborescence": {
#         "arguments": [
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Result<(usize, impl Iterator<Item = (NodeT, NodeT)> + '_), String>"
#     },
#     "connected_components": {
#         "arguments": [
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Result<(Vec<NodeT>, NodeT, NodeT, NodeT), String>"
#     },
#     "overlaps": {
#         "arguments": [
#             [
#                 "other",
#                 "&Graph"
#             ]
#         ],
#         "return_type": "Result<bool, String>"
#     },
#     "contains": {
#         "arguments": [
#             [
#                 "other",
#                 "&Graph"
#             ]
#         ],
#         "return_type": "Result<bool, String>"
#     },
#     "get_node_label_prediction_tuple_by_node_ids": {
#         "arguments": [
#             [
#                 "node_ids",
#                 "Vec<NodeT>"
#             ],
#             [
#                 "random_state",
#                 "u64"
#             ],
#             [
#                 "include_central_node",
#                 "bool"
#             ],
#             [
#                 "offset",
#                 "NodeT"
#             ],
#             [
#                 "max_neighbours",
#                 "Option<NodeT>"
#             ]
#         ],
#         "return_type": "Result<        impl Iterator<Item = (impl Iterator<Item = NodeT> + '_, Option<Vec<NodeTypeT>>)> + '_,        String,    >"
#     },
#     "are_nodes_remappable": {
#         "arguments": [
#             [
#                 "other",
#                 "&Graph"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "remap": {
#         "arguments": [
#             [
#                 "other",
#                 "&Graph"
#             ],
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "is_singleton_by_node_id": {
#         "arguments": [
#             [
#                 "node_id",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Result<bool, String>"
#     },
#     "is_singleton_with_selfloops_by_node_id": {
#         "arguments": [
#             [
#                 "node_id",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "is_singleton_by_node_name": {
#         "arguments": [
#             [
#                 "node_name",
#                 "&str"
#             ]
#         ],
#         "return_type": "Result<bool, String>"
#     },
#     "has_node_by_node_name": {
#         "arguments": [
#             [
#                 "node_name",
#                 "&str"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "has_edge_by_node_ids": {
#         "arguments": [
#             [
#                 "src",
#                 "NodeT"
#             ],
#             [
#                 "dst",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "has_edge_with_type_by_node_ids": {
#         "arguments": [
#             [
#                 "src",
#                 "NodeT"
#             ],
#             [
#                 "dst",
#                 "NodeT"
#             ],
#             [
#                 "edge_type",
#                 "Option<EdgeTypeT>"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "is_trap_node_by_node_id": {
#         "arguments": [
#             [
#                 "node_id",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Result<bool, String>"
#     },
#     "has_node_with_type_by_node_name": {
#         "arguments": [
#             [
#                 "node_name",
#                 "&str"
#             ],
#             [
#                 "node_type_name",
#                 "Option<Vec<String>>"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "has_edge_by_node_names": {
#         "arguments": [
#             [
#                 "src_name",
#                 "&str"
#             ],
#             [
#                 "dst_name",
#                 "&str"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "has_edge_with_type_by_node_names": {
#         "arguments": [
#             [
#                 "src_name",
#                 "&str"
#             ],
#             [
#                 "dst_name",
#                 "&str"
#             ],
#             [
#                 "edge_type_name",
#                 "Option<&String>"
#             ]
#         ],
#         "return_type": "bool"
#     },
#     "enable": {
#         "arguments": [
#             [
#                 "vector_sources",
#                 "bool"
#             ],
#             [
#                 "vector_destinations",
#                 "bool"
#             ],
#             [
#                 "vector_outbounds",
#                 "bool"
#             ],
#             [
#                 "cache_size",
#                 "Option<f64>"
#             ]
#         ],
#         "return_type": "Result<(), String>"
#     },
#     "get_edge_quadruple": {
#         "arguments": [
#             [
#                 "edge_id",
#                 "EdgeT"
#             ]
#         ],
#         "return_type": "(NodeT, NodeT, Option<EdgeTypeT>, Option<WeightT>)"
#     },
#     "get_edge_triple": {
#         "arguments": [
#             [
#                 "edge_id",
#                 "EdgeT"
#             ]
#         ],
#         "return_type": "(NodeT, NodeT, Option<EdgeTypeT>)"
#     },
#     "get_top_k_central_nodes_ids": {
#         "arguments": [
#             [
#                 "k",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Vec<NodeT>"
#     },
#     "get_top_k_central_node_names": {
#         "arguments": [
#             [
#                 "k",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Vec<String>"
#     },
#     "get_node_type_id_by_node_id": {
#         "arguments": [
#             [
#                 "node_id",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Result<Option<Vec<NodeTypeT>>, String>"
#     },
#     "get_edge_type_id_by_edge_id": {
#         "arguments": [
#             [
#                 "edge_id",
#                 "EdgeT"
#             ]
#         ],
#         "return_type": "Result<Option<EdgeTypeT>, String>"
#     },
#     "get_node_type_name_by_node_id": {
#         "arguments": [
#             [
#                 "node_id",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Result<Option<Vec<String>>, String>"
#     },
#     "get_edge_type_name_by_edge_id": {
#         "arguments": [
#             [
#                 "edge_id",
#                 "EdgeT"
#             ]
#         ],
#         "return_type": "Result<Option<String>, String>"
#     },
#     "get_edge_type_name_by_edge_type_id": {
#         "arguments": [
#             [
#                 "edge_type_id",
#                 "EdgeTypeT"
#             ]
#         ],
#         "return_type": "Result<String, String>"
#     },
#     "get_weight_by_edge_id": {
#         "arguments": [
#             [
#                 "edge_id",
#                 "EdgeT"
#             ]
#         ],
#         "return_type": "Result<WeightT, String>"
#     },
#     "get_weight_by_node_ids": {
#         "arguments": [
#             [
#                 "src",
#                 "NodeT"
#             ],
#             [
#                 "dst",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Result<WeightT, String>"
#     },
#     "get_weight_with_type_by_node_ids": {
#         "arguments": [
#             [
#                 "src",
#                 "NodeT"
#             ],
#             [
#                 "dst",
#                 "NodeT"
#             ],
#             [
#                 "edge_type",
#                 "Option<EdgeTypeT>"
#             ]
#         ],
#         "return_type": "Result<WeightT, String>"
#     },
#     "get_weight_with_type_by_node_names": {
#         "arguments": [
#             [
#                 "src",
#                 "&str"
#             ],
#             [
#                 "dst",
#                 "&str"
#             ],
#             [
#                 "edge_type",
#                 "Option<&String>"
#             ]
#         ],
#         "return_type": "Result<WeightT, String>"
#     },
#     "get_weight_by_node_names": {
#         "arguments": [
#             [
#                 "src_name",
#                 "&str"
#             ],
#             [
#                 "dst_name",
#                 "&str"
#             ]
#         ],
#         "return_type": "Result<WeightT, String>"
#     },
#     "get_node_name_by_node_id": {
#         "arguments": [
#             [
#                 "node_id",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Result<String, String>"
#     },
#     "get_node_id_by_node_name": {
#         "arguments": [
#             [
#                 "node_name",
#                 "&str"
#             ]
#         ],
#         "return_type": "Result<NodeT, String>"
#     },
#     "get_node_type_id_by_node_name": {
#         "arguments": [
#             [
#                 "node_name",
#                 "&str"
#             ]
#         ],
#         "return_type": "Result<Option<Vec<NodeTypeT>>, String>"
#     },
#     "get_node_type_name_by_node_name": {
#         "arguments": [
#             [
#                 "node_name",
#                 "&str"
#             ]
#         ],
#         "return_type": "Result<Option<Vec<String>>, String>"
#     },
#     "get_edge_count_by_edge_type_id": {
#         "arguments": [
#             [
#                 "edge_type",
#                 "Option<EdgeTypeT>"
#             ]
#         ],
#         "return_type": "Result<EdgeT, String>"
#     },
#     "get_edge_type_id_by_edge_type_name": {
#         "arguments": [
#             [
#                 "edge_type_name",
#                 "Option<&str>"
#             ]
#         ],
#         "return_type": "Result<Option<EdgeTypeT>, String>"
#     },
#     "get_edge_count_by_edge_type_name": {
#         "arguments": [
#             [
#                 "edge_type",
#                 "Option<&str>"
#             ]
#         ],
#         "return_type": "Result<EdgeT, String>"
#     },
#     "get_node_type_id_by_node_type_name": {
#         "arguments": [
#             [
#                 "node_type_name",
#                 "&str"
#             ]
#         ],
#         "return_type": "Result<NodeTypeT, String>"
#     },
#     "get_node_count_by_node_type_id": {
#         "arguments": [
#             [
#                 "node_type",
#                 "Option<NodeTypeT>"
#             ]
#         ],
#         "return_type": "Result<NodeT, String>"
#     },
#     "get_node_count_by_node_type_name": {
#         "arguments": [
#             [
#                 "node_type_name",
#                 "Option<&str>"
#             ]
#         ],
#         "return_type": "Result<NodeT, String>"
#     },
#     "get_destination_node_id_by_edge_id": {
#         "arguments": [
#             [
#                 "edge_id",
#                 "EdgeT"
#             ]
#         ],
#         "return_type": "Result<NodeT, String>"
#     },
#     "get_node_neighbours_by_node_id": {
#         "arguments": [
#             [
#                 "node_id",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Result<Vec<NodeT>, String>"
#     },
#     "get_node_neighbour_ids_by_node_name": {
#         "arguments": [
#             [
#                 "node_name",
#                 "&str"
#             ]
#         ],
#         "return_type": "Result<Vec<NodeT>, String>"
#     },
#     "get_node_neighbour_names_by_node_name": {
#         "arguments": [
#             [
#                 "node_name",
#                 "&str"
#             ]
#         ],
#         "return_type": "Result<Vec<String>, String>"
#     },
#     "get_edge_id_with_type_by_node_ids": {
#         "arguments": [
#             [
#                 "src",
#                 "NodeT"
#             ],
#             [
#                 "dst",
#                 "NodeT"
#             ],
#             [
#                 "edge_type",
#                 "Option<EdgeTypeT>"
#             ]
#         ],
#         "return_type": "Result<EdgeT, String>"
#     },
#     "get_edge_id_by_node_names": {
#         "arguments": [
#             [
#                 "src_name",
#                 "&str"
#             ],
#             [
#                 "dst_name",
#                 "&str"
#             ]
#         ],
#         "return_type": "Result<EdgeT, String>"
#     },
#     "get_edge_id_with_type_by_node_names": {
#         "arguments": [
#             [
#                 "src_name",
#                 "&str"
#             ],
#             [
#                 "dst_name",
#                 "&str"
#             ],
#             [
#                 "edge_type_name",
#                 "Option<&String>"
#             ]
#         ],
#         "return_type": "Result<EdgeT, String>"
#     },
#     "get_edge_type_ids_by_edge_type_names": {
#         "arguments": [
#             [
#                 "edge_types",
#                 "Vec<Option<String>>"
#             ]
#         ],
#         "return_type": "Result<Vec<Option<EdgeTypeT>>, String>"
#     },
#     "get_node_type_ids_by_node_type_names": {
#         "arguments": [
#             [
#                 "node_types",
#                 "Vec<Option<String>>"
#             ]
#         ],
#         "return_type": "Result<Vec<Option<NodeTypeT>>, String>"
#     },
#     "get_node_type_name_by_node_type_id": {
#         "arguments": [
#             [
#                 "node_type_id",
#                 "NodeTypeT"
#             ]
#         ],
#         "return_type": "Result<String, String>"
#     },
#     "get_node_type_names_by_node_type_ids": {
#         "arguments": [
#             [
#                 "node_type_ids",
#                 "Vec<NodeTypeT>"
#             ]
#         ],
#         "return_type": "Result<Vec<String>, String>"
#     },
#     "get_node_degree_by_node_id": {
#         "arguments": [
#             [
#                 "node_id",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Result<NodeT, String>"
#     },
#     "filter": {
#         "arguments": [
#             [
#                 "node_names",
#                 "Option<Vec<String>>"
#             ],
#             [
#                 "node_types",
#                 "Option<Vec<Option<String>>>"
#             ],
#             [
#                 "edge_types",
#                 "Option<Vec<Option<String>>>"
#             ],
#             [
#                 "min_weight",
#                 "Option<WeightT>"
#             ],
#             [
#                 "max_weight",
#                 "Option<WeightT>"
#             ],
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "degrees_product": {
#         "arguments": [
#             [
#                 "one",
#                 "NodeT"
#             ],
#             [
#                 "two",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Result<usize, String>"
#     },
#     "jaccard_index": {
#         "arguments": [
#             [
#                 "one",
#                 "NodeT"
#             ],
#             [
#                 "two",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Result<f64, String>"
#     },
#     "adamic_adar_index": {
#         "arguments": [
#             [
#                 "one",
#                 "NodeT"
#             ],
#             [
#                 "two",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Result<f64, String>"
#     },
#     "resource_allocation_index": {
#         "arguments": [
#             [
#                 "one",
#                 "NodeT"
#             ],
#             [
#                 "two",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Result<f64, String>"
#     },
#     "connected_components_number": {
#         "arguments": [
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "(NodeT, NodeT, NodeT)"
#     },
#     "overlap_textual_report": {
#         "arguments": [
#             [
#                 "other",
#                 "&Graph"
#             ],
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Result<String, String>"
#     },
#     "textual_report": {
#         "arguments": [
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Result<String, String>"
#     },
#     "remove": {
#         "arguments": [
#             [
#                 "allow_nodes_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "deny_nodes_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "allow_node_types_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "deny_node_types_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "allow_edge_set",
#                 "Option<HashSet<EdgeT>>"
#             ],
#             [
#                 "deny_edge_set",
#                 "Option<HashSet<EdgeT>>"
#             ],
#             [
#                 "allow_edge_types_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "deny_edge_types_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "weights",
#                 "bool"
#             ],
#             [
#                 "node_types",
#                 "bool"
#             ],
#             [
#                 "edge_types",
#                 "bool"
#             ],
#             [
#                 "singletons",
#                 "bool"
#             ],
#             [
#                 "selfloops",
#                 "bool"
#             ],
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "remove_components": {
#         "arguments": [
#             [
#                 "node_names",
#                 "Option<Vec<String>>"
#             ],
#             [
#                 "node_types",
#                 "Option<Vec<Option<String>>>"
#             ],
#             [
#                 "edge_types",
#                 "Option<Vec<Option<String>>>"
#             ],
#             [
#                 "minimum_component_size",
#                 "Option<NodeT>"
#             ],
#             [
#                 "top_k_components",
#                 "Option<NodeT>"
#             ],
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "encode_edge": {
#         "arguments": [
#             [
#                 "src",
#                 "NodeT"
#             ],
#             [
#                 "dst",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "u64"
#     },
#     "decode_edge": {
#         "arguments": [
#             [
#                 "edge",
#                 "u64"
#             ]
#         ],
#         "return_type": "(NodeT, NodeT)"
#     },
#     "get_edge_id_by_node_ids": {
#         "arguments": [
#             [
#                 "src",
#                 "NodeT"
#             ],
#             [
#                 "dst",
#                 "NodeT"
#             ]
#         ],
#         "return_type": "Result<EdgeT, String>"
#     },
#     "get_bipartite_edges": {
#         "arguments": [
#             [
#                 "removed_existing_edges",
#                 "Option<bool>"
#             ],
#             [
#                 "first_nodes_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "second_nodes_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "first_node_types_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "second_node_types_set",
#                 "Option<HashSet<String>>"
#             ]
#         ],
#         "return_type": "Result<Vec<Vec<NodeT>>, String>"
#     },
#     "get_bipartite_edge_names": {
#         "arguments": [
#             [
#                 "removed_existing_edges",
#                 "Option<bool>"
#             ],
#             [
#                 "first_nodes_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "second_nodes_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "first_node_types_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "second_node_types_set",
#                 "Option<HashSet<String>>"
#             ]
#         ],
#         "return_type": "Result<Vec<Vec<String>>, String>"
#     },
#     "get_star_edges": {
#         "arguments": [
#             [
#                 "central_node",
#                 "String"
#             ],
#             [
#                 "removed_existing_edges",
#                 "Option<bool>"
#             ],
#             [
#                 "star_points_nodes_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "star_points_node_types_set",
#                 "Option<HashSet<String>>"
#             ]
#         ],
#         "return_type": "Result<Vec<Vec<NodeT>>, String>"
#     },
#     "get_star_edge_names": {
#         "arguments": [
#             [
#                 "central_node",
#                 "String"
#             ],
#             [
#                 "removed_existing_edges",
#                 "Option<bool>"
#             ],
#             [
#                 "star_points_nodes_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "star_points_node_types_set",
#                 "Option<HashSet<String>>"
#             ]
#         ],
#         "return_type": "Result<Vec<Vec<String>>, String>"
#     },
#     "get_clique_edges": {
#         "arguments": [
#             [
#                 "directed",
#                 "Option<bool>"
#             ],
#             [
#                 "allow_selfloops",
#                 "Option<bool>"
#             ],
#             [
#                 "removed_existing_edges",
#                 "Option<bool>"
#             ],
#             [
#                 "allow_node_type_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "allow_node_set",
#                 "Option<HashSet<String>>"
#             ]
#         ],
#         "return_type": "Vec<Vec<NodeT>>"
#     },
#     "get_clique_edge_names": {
#         "arguments": [
#             [
#                 "directed",
#                 "Option<bool>"
#             ],
#             [
#                 "allow_selfloops",
#                 "Option<bool>"
#             ],
#             [
#                 "removed_existing_edges",
#                 "Option<bool>"
#             ],
#             [
#                 "allow_node_type_set",
#                 "Option<HashSet<String>>"
#             ],
#             [
#                 "allow_node_set",
#                 "Option<HashSet<String>>"
#             ]
#         ],
#         "return_type": "Vec<Vec<String>>"
#     },
#     "get_sources": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "Vec<NodeT>"
#     },
#     "get_source_names": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "Vec<String>"
#     },
#     "get_destinations": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "Vec<NodeT>"
#     },
#     "get_destination_names": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "Vec<String>"
#     },
#     "get_edges": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "Vec<Vec<NodeT>>"
#     },
#     "get_edge_names": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "Vec<(String, String)>"
#     },
#     "get_node_components_vector": {
#         "arguments": [
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Vec<NodeT>"
#     },
#     "iter_sources_ids": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl Iterator<Item = NodeT> + '_"
#     },
#     "par_iter_sources_ids": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = NodeT> + '_"
#     },
#     "iter_destinations_ids": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl Iterator<Item = NodeT> + '_"
#     },
#     "par_iter_destinations_ids": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = NodeT> + '_"
#     },
#     "iter_nodes": {
#         "arguments": [],
#         "return_type": "impl Iterator<Item = (NodeT, String, Option<Vec<NodeTypeT>>, Option<Vec<String>>)> + '_"
#     },
#     "iter_edge_ids": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "Box<dyn Iterator<Item = (EdgeT, NodeT, NodeT)> + '_>"
#     },
#     "iter_edges": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl Iterator<Item = (EdgeT, NodeT, String, NodeT, String)> + '_"
#     },
#     "par_iter_edge_ids": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = (EdgeT, NodeT, NodeT)> + '_"
#     },
#     "par_iter_edges": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = (EdgeT, NodeT, String, NodeT, String)> + '_"
#     },
#     "iter_edges_with_type_ids": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl Iterator<Item = (EdgeT, NodeT, NodeT, Option<EdgeTypeT>)> + '_"
#     },
#     "iter_edges_with_type": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl Iterator<        Item = (            EdgeT,            NodeT,            String,            NodeT,            String,            Option<EdgeTypeT>,            Option<String>,        ),    > + '_"
#     },
#     "par_iter_edge_with_type": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl ParallelIterator<        Item = (            EdgeT,            NodeT,            String,            NodeT,            String,            Option<EdgeTypeT>,            Option<String>,        ),    > + '_"
#     },
#     "par_iter_edge_with_type_ids": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = (EdgeT, NodeT, NodeT, Option<EdgeTypeT>)> + '_"
#     },
#     "par_iter_edge_with_type_and_weight": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl ParallelIterator<        Item = (            EdgeT,            NodeT,            String,            NodeT,            String,            Option<EdgeTypeT>,            Option<String>,            Option<WeightT>,        ),    > + '_"
#     },
#     "iter_edge_with_type_and_weight": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl Iterator<        Item = (            EdgeT,            NodeT,            String,            NodeT,            String,            Option<EdgeTypeT>,            Option<String>,            Option<WeightT>,        ),    > + '_"
#     },
#     "par_iter_edge_with_type_and_weight_ids": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl ParallelIterator<Item = (EdgeT, NodeT, NodeT, Option<EdgeTypeT>, Option<WeightT>)> + '_"
#     },
#     "iter_edge_with_type_and_weight_ids": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "impl Iterator<Item = (EdgeT, NodeT, NodeT, Option<EdgeTypeT>, Option<WeightT>)> + '_"
#     },
#     "iter_unique_edges": {
#         "arguments": [
#             [
#                 "directed",
#                 "bool"
#             ]
#         ],
#         "return_type": "Box<dyn Iterator<Item = (NodeT, NodeT)> + '_>"
#     },
#     "sample_negatives": {
#         "arguments": [
#             [
#                 "random_state",
#                 "EdgeT"
#             ],
#             [
#                 "negatives_number",
#                 "EdgeT"
#             ],
#             [
#                 "seed_graph",
#                 "Option<&Graph>"
#             ],
#             [
#                 "only_from_same_component",
#                 "bool"
#             ],
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "connected_holdout": {
#         "arguments": [
#             [
#                 "random_state",
#                 "EdgeT"
#             ],
#             [
#                 "train_size",
#                 "f64"
#             ],
#             [
#                 "edge_types",
#                 "Option<Vec<Option<String>>>"
#             ],
#             [
#                 "include_all_edge_types",
#                 "bool"
#             ],
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Result<(Graph, Graph), String>"
#     },
#     "random_holdout": {
#         "arguments": [
#             [
#                 "random_state",
#                 "EdgeT"
#             ],
#             [
#                 "train_size",
#                 "f64"
#             ],
#             [
#                 "include_all_edge_types",
#                 "bool"
#             ],
#             [
#                 "edge_types",
#                 "Option<Vec<Option<String>>>"
#             ],
#             [
#                 "min_number_overlaps",
#                 "Option<EdgeT>"
#             ],
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Result<(Graph, Graph), String>"
#     },
#     "node_label_holdout": {
#         "arguments": [
#             [
#                 "train_size",
#                 "f64"
#             ],
#             [
#                 "use_stratification",
#                 "bool"
#             ],
#             [
#                 "random_state",
#                 "EdgeT"
#             ]
#         ],
#         "return_type": "Result<(Graph, Graph), String>"
#     },
#     "edge_label_holdout": {
#         "arguments": [
#             [
#                 "train_size",
#                 "f64"
#             ],
#             [
#                 "use_stratification",
#                 "bool"
#             ],
#             [
#                 "random_state",
#                 "EdgeT"
#             ]
#         ],
#         "return_type": "Result<(Graph, Graph), String>"
#     },
#     "random_subgraph": {
#         "arguments": [
#             [
#                 "random_state",
#                 "usize"
#             ],
#             [
#                 "nodes_number",
#                 "NodeT"
#             ],
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Result<Graph, String>"
#     },
#     "kfold": {
#         "arguments": [
#             [
#                 "k",
#                 "EdgeT"
#             ],
#             [
#                 "k_index",
#                 "u64"
#             ],
#             [
#                 "edge_types",
#                 "Option<Vec<Option<String>>>"
#             ],
#             [
#                 "random_state",
#                 "EdgeT"
#             ],
#             [
#                 "verbose",
#                 "bool"
#             ]
#         ],
#         "return_type": "Result<(Graph, Graph), String>"
#     }
# }

# %%
def filter_function(function_name, infos):
    return function_name in [
        "validate_weight",
        "parse_weight",
        "has_edge"
        
    ] or any(
        e in arg[1]
        for arg in infos["arguments"]
        for e in [
            "impl", 
            "Fn", 
            "Iter", 
            "NodeFileReader", 
            "EdgeFileReader", 
            "Graph", 
            "Compute_hash_Params",
            "&str",
            "&[u32]",
            "&String",
            "SingleWalkParameters",
            "WalksParameters",
            "WalkWeights",
            "Self",
            "&[String]",
            "&"
        ]
    )

# %%
structs = []
fields = []

template = """
#[derive(Arbitrary, Debug, Clone)]
pub struct %s {
# %s
}
"""

for function_name, info in functions_info.items():
    
    # Check if the function has parameters (other than self)
    if len(info["arguments"]) == 0:
        continue
        
    if filter_function(function_name, info):
        print("\n\nSkipping ", function_name)
        print(info["arguments"])
        continue
        
    
    struct_name = function_name.capitalize() + "_Params"
    
    fields.append("\tpub {function_name} : {struct_name},".format(
        function_name=function_name, 
        struct_name=struct_name,
    ))
        
          
    struct = template%(
        struct_name,
        "\n".join([
            "\tpub {field_name} : {field_type},".format(
                field_name=arg_name,
                field_type=arg_type,
            )
        for arg_name, arg_type in info["arguments"]
        ])
    )
    
    structs.append(struct)
    
    
fields.append( "\tpub from_vec: FromVecHarnessParams,")

harness = template%(
    "TheUltimateFuzzer",
    "\n".join(fields)
)
structs.append(harness)
    
result = "\n".join(structs)
# Out:
# Skipping  random_spanning_arborescence_kruskal
# [('random_state', 'EdgeT'), ('unwanted_edge_types', '&Option<HashSet<Option<EdgeTypeT>>>'), ('verbose', 'bool')]
#
#
# Skipping  overlaps
# [('other', '&Graph')]
#
#
# Skipping  contains
# [('other', '&Graph')]
#
#
# Skipping  are_nodes_remappable
# [('other', '&Graph')]
#
#
# Skipping  remap
# [('other', '&Graph'), ('verbose', 'bool')]
#
#
# Skipping  is_singleton_by_node_name
# [('node_name', '&str')]
#
#
# Skipping  has_node_by_node_name
# [('node_name', '&str')]
#
#
# Skipping  has_node_with_type_by_node_name
# [('node_name', '&str'), ('node_type_name', 'Option<Vec<String>>')]
#
#
# Skipping  has_edge_by_node_names
# [('src_name', '&str'), ('dst_name', '&str')]
#
#
# Skipping  has_edge_with_type_by_node_names
# [('src_name', '&str'), ('dst_name', '&str'), ('edge_type_name', 'Option<&String>')]
#
#
# Skipping  get_weight_with_type_by_node_names
# [('src', '&str'), ('dst', '&str'), ('edge_type', 'Option<&String>')]
#
#
# Skipping  get_weight_by_node_names
# [('src_name', '&str'), ('dst_name', '&str')]
#
#
# Skipping  get_node_id_by_node_name
# [('node_name', '&str')]
#
#
# Skipping  get_node_type_id_by_node_name
# [('node_name', '&str')]
#
#
# Skipping  get_node_type_name_by_node_name
# [('node_name', '&str')]
#
#
# Skipping  get_edge_type_id_by_edge_type_name
# [('edge_type_name', 'Option<&str>')]
#
#
# Skipping  get_edge_count_by_edge_type_name
# [('edge_type', 'Option<&str>')]
#
#
# Skipping  get_node_type_id_by_node_type_name
# [('node_type_name', '&str')]
#
#
# Skipping  get_node_count_by_node_type_name
# [('node_type_name', 'Option<&str>')]
#
#
# Skipping  get_node_neighbour_ids_by_node_name
# [('node_name', '&str')]
#
#
# Skipping  get_node_neighbour_names_by_node_name
# [('node_name', '&str')]
#
#
# Skipping  get_edge_id_by_node_names
# [('src_name', '&str'), ('dst_name', '&str')]
#
#
# Skipping  get_edge_id_with_type_by_node_names
# [('src_name', '&str'), ('dst_name', '&str'), ('edge_type_name', 'Option<&String>')]
#
#
# Skipping  overlap_textual_report
# [('other', '&Graph'), ('verbose', 'bool')]
#
#
# Skipping  sample_negatives
# [('random_state', 'EdgeT'), ('negatives_number', 'EdgeT'), ('seed_graph', 'Option<&Graph>'), ('only_from_same_component', 'bool'), ('verbose', 'bool')]

# %%
len(structs)
# Out:
# 82

# %%
def build_call(function_name, infos):
    if filter_function(function_name, infos):
        return ""
    
    args = ", ".join([
        f"data.{function_name}.{arg[0]}"
        for arg in infos["arguments"]
    ])
    
    result = f"\tgraph.{function_name}({args})"
    
    if infos["return_type"].startswith("Result"):
        result += "?"
    
    return result + ";"

# %%
harness = """
pub fn mega_test(data: TheUltimateFuzzer) -> Result<(), String> {
    let data_copy = data.clone();
    let data_copy2 = data.clone();
    std::panic::set_hook(Box::new(move |info| {
        handle_panics_mega_test(info, data_copy.clone());
    }));

    let mut graph = graph::Graph::from_string_unsorted(
        data.from_vec.edges.into_iter(),
        data.from_vec.nodes.map(|ns| ns.into_iter()),
        data.from_vec.directed,
        data.from_vec.directed_edge_list,
        data.from_vec.name,
        data.from_vec.ignore_duplicated_nodes,
        data.from_vec.ignore_duplicated_edges,
        data.from_vec.verbose,
        data.from_vec.numeric_edge_types_ids,
        data.from_vec.numeric_node_ids,
        data.from_vec.numeric_edge_node_ids,
        data.from_vec.numeric_node_types_ids,
        data.from_vec.has_node_types,
        data.from_vec.has_edge_types,
        data.from_vec.has_edge_weights,
    )?;
    
    

    let g_copy = graph.clone();
    std::panic::set_hook(Box::new(move |info| {
        handle_panics_mega_test_once_loaded(info, data_copy2.clone(), g_copy.clone());
    }));

    
# %s

    Ok(())
}
"""%"\n".join(
    build_call(function_name, infos)
    for function_name, infos in functions_info.items()
)

# %%
with open("result.rs", "w") as f:
    f.write(setup + result + harness)
